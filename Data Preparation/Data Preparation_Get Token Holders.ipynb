# %%
# To display full output in Notebook, instead of only the last result
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import requests
import json
import time
from bech32 import bech32_encode, convertbits

from datetime import datetime
from tqdm import tqdm
from bech32 import bech32_decode, convertbits
from binascii import hexlify

# %%
path = "/home/jovyan/work/New Topic/DeFi.csv"
defi_policy_id_df = pd.read_csv(path)

# %%
defi_policy_id_df
# Out:
#   Category     DeFi Name                                         Token Link  \
# 0      DEX  Genius Yield  https://cexplorer.io/asset/asset1266q2ewhgul7j...
# 1      DEX    Muesliswap  https://cexplorer.io/asset/asset1pwhywk7x54g73...
# 2      DEX       Minswap  https://cexplorer.io/asset/asset1d9v7aptfvpx7w...
# 3      DEX    Wingriders  https://cexplorer.io/asset/asset18v68f0vgv2nc3...
# 4      DEX    SundaeSwap  https://cexplorer.io/asset/asset1m4u92ke6820pk...
#
#   Token Name                                          Policy ID
# 0       GENS  dda5fdb1002f7389b33e036b6afee82a8189becb6cba85...
# 1       MILK  8a1cfae21368b8bebbbed9800fec304e95cce39a2a57dc...
# 2        MIN  29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a8...
# 3        WRT  c0ee29a85b13209423b10447d3c2e6a50641a15c57770e...
# 4     SUNDAE  9a9693a9a37912a5097918f97918d15240c92ab729a0b7...

# %%
def bech32_to_hex(addr_bech32: str) -> str:
    hrp, data = bech32_decode(addr_bech32)
    if data is None:
        raise ValueError(f"Invalid bech32 address: {addr_bech32}")
    decoded = convertbits(data, 5, 8, False)
    return hexlify(bytes(decoded)).decode()

def safe_bech32_to_hex(addr):
    if pd.isna(addr):
        return None
    try:
        return bech32_to_hex(addr)
    except Exception:
        return None

def hex_to_bech32(addr_hex: str, hrp="addr") -> str:
    """Convert 128-char hex string to bech32 address."""
    data = bytes.fromhex(addr_hex)
    five_bit = convertbits(data, 8, 5)
    return bech32_encode(hrp, five_bit)


def safe_hex_to_bech32(addr_hex: str, hrp="addr") -> str:
    """Convert 128-char hex string to bech32 address with error handling."""
    try:
        data = bytes.fromhex(addr_hex)
        five_bit = convertbits(data, 8, 5)
        return bech32_encode(hrp, five_bit)
    except Exception as e:
        return None

# %%
# Your API key
CARDANOSCAN_API_KEY = "520c718b-75dc-4898-aeca-199e059de866"

# %%
import requests
import pandas as pd
import time
import json
import re

# Your API key
CARDANOSCAN_API_KEY = "520c718b-75dc-4898-aeca-199e059de866"

# Containers for results
all_assets = {}
failures = {}

# Helper: validate policy ID format
def is_valid_policy_id(pid):
    return isinstance(pid, str) and len(pid) == 56 and re.fullmatch(r'[0-9a-fA-F]{56}', pid)

# Loop through each policy ID
for i, row in defi_policy_id_df.iterrows():
    policy_id = row["Policy ID"]
    defi_name = row["DeFi Name"]

    if not is_valid_policy_id(policy_id):
        print(f"⚠️ Skipping {defi_name}: Invalid policy ID format → {policy_id}")
        failures[defi_name] = "Invalid policy ID format"
        continue

    print(f"🔍 Fetching for {defi_name} ({policy_id[:10]}...)")
    assets = []
    page = 1

    while True:
        url = f"https://api.cardanoscan.io/api/v1/asset/list/byPolicyId?policyId={policy_id}&pageNo={page}"
        headers = {"apiKey": CARDANOSCAN_API_KEY}

        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            data = response.json()

            # ✅ FIXED: Use "tokens" field instead of "data"
            page_assets = data.get("tokens", [])
            if not page_assets:
                break

            assets.extend(page_assets)
            page += 1
            time.sleep(1.2)  # Be polite to the API

        except Exception as e:
            print(f"❌ Failed on page {page} for {defi_name}: {e}")
            failures[defi_name] = str(e)
            break

    all_assets[defi_name] = assets
    print(f"✅ {defi_name}: {len(assets)} assets retrieved")

# Save successful results
with open("defi_assets_by_policy.json", "w") as f:
    json.dump(all_assets, f, indent=2)

# Save failure log if any
if failures:
    with open("defi_asset_failures.json", "w") as f:
        json.dump(failures, f, indent=2)
    print(f"⚠️ Some fetches failed. See 'defi_asset_failures.json' for details.")

print("🎉 Done! All data saved to 'defi_assets_by_policy.json'")
# Out:
# 🔍 Fetching for Genius Yield (dda5fdb100...)
# ✅ Genius Yield: 2 assets retrieved
# 🔍 Fetching for Muesliswap (8a1cfae213...)
# ✅ Muesliswap: 1 assets retrieved
# 🔍 Fetching for Minswap (29d222ce76...)
# ✅ Minswap: 3 assets retrieved
# 🔍 Fetching for Wingriders (c0ee29a85b...)
# ✅ Wingriders: 1 assets retrieved
# 🔍 Fetching for SundaeSwap (9a9693a9a3...)
# ✅ SundaeSwap: 1 assets retrieved
# 🎉 Done! All data saved to 'defi_assets_by_policy.json'

# %%
# !curl --request GET \
  --url "https://api.cardanoscan.io/api/v1/asset/list/byPolicyId?policyId=29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c6&pageNo=1" \
  --header "apiKey: 520c718b-75dc-4898-aeca-199e059de866"
# Out:
# {"tokens":[{"policyId":"29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c6","assetName":"4d494e","fingerprint":"6959ee8569604de7655fe9d2aa59c11da4adf683","assetId":"29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c64d494e","totalSupply":"3000000000000000","txCount":4129320,"mintedOn":"2021-10-10T10:17:49.000Z"},{"policyId":"29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c6","assetName":"4d494e74","fingerprint":"55df7e8b8f955ac65aba1dc984a3c2f95657be7f","assetId":"29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c64d494e74","totalSupply":"45785504224419","txCount":493837,"mintedOn":"2021-12-07T11:03:39.000Z"},{"policyId":"29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c6","assetName":"346434393465","fingerprint":"7b133f04d855b81841b0699c720e6842eea4caa8","assetId":"29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c6346434393465","totalSupply":"0","txCount":3,"mintedOn":"2022-01-10T04:50:08.000Z"}],"count":3,"pageNo":1,"limit":20}

# %% [markdown]
# # Get Token User Holders from Blockfrost

# %%
import requests
import time
import json
from datetime import datetime

# === CONFIGURATION ===
BLOCKFROST_API_KEY = "mainnetD5tXDiNzInPOA8ABiVQjb9gBJxB2zqXu"
ASSET_CONCAT_ID = "dda5fdb1002f7389b33e036b6afee82a8189becb6cba852e8b79b4fb0014df1047454e53"
OUTPUT_PATH = "genius_yield_gens_holders.json"
MAX_RETRIES = 3
SLEEP_BETWEEN_PAGES = 0.8

# === INIT ===
url_base = f"https://cardano-mainnet.blockfrost.io/api/v0/assets/{ASSET_CONCAT_ID}/addresses"
headers = {"project_id": BLOCKFROST_API_KEY}
holders = []
page = 1
fetching = True

# === PAGINATED FETCH ===
while fetching:
    url = f"{url_base}?page={page}"
    attempt = 1
    success = False

    while attempt <= MAX_RETRIES:
        try:
            response = requests.get(url, headers=headers, timeout=20)

            # Check if response is JSON
            if "application/json" not in response.headers.get("Content-Type", ""):
                print(f"❌ HTML error received instead of JSON on page {page}")
                print(f"📎 Response snippet:\n{response.text[:300]}")
                raise ValueError("Non-JSON response received")

            if response.status_code == 200:
                page_data = response.json()

                if not page_data:
                    print(f"🚫 Page {page} is empty. Stopping fetch.")
                    fetching = False  # ✅ Stop the outer loop
                    success = True
                    break

                holders.extend(page_data)
                print(f"✅ Page {page}: {len(page_data)} addresses fetched")
                success = True
                break
            else:
                print(f"⚠️ Attempt {attempt}: {response.status_code} - {response.text}")

        except Exception as e:
            print(f"⚠️ Attempt {attempt}: Exception - {e}")

        attempt += 1
        time.sleep(3)

    if not success:
        print(f"❌ Failed to fetch page {page}. Stopping.")
        break

    page += 1
    try:
        time.sleep(SLEEP_BETWEEN_PAGES)
    except KeyboardInterrupt:
        print("🛑 Manually interrupted during sleep. Exiting fetch loop.")
        break

# === SAVE TO FILE ===
if holders:
    with open(OUTPUT_PATH, "w") as f:
        json.dump(holders, f, indent=2)
    print(f"🎉 Done! Total holders: {len(holders)}. Saved to '{OUTPUT_PATH}'")
else:
    print("⚠️ No data saved. Holder list is empty.")

print(f"✅ Script finished at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ Page 1: 100 addresses fetched
# ✅ Page 2: 100 addresses fetched
# ✅ Page 3: 100 addresses fetched
# ✅ Page 4: 100 addresses fetched
# ✅ Page 5: 100 addresses fetched
# ✅ Page 6: 100 addresses fetched
# ✅ Page 7: 100 addresses fetched
# ✅ Page 8: 100 addresses fetched
# ✅ Page 9: 100 addresses fetched
# ✅ Page 10: 100 addresses fetched
# ✅ Page 11: 100 addresses fetched
# ✅ Page 12: 100 addresses fetched
# ✅ Page 13: 100 addresses fetched
# ✅ Page 14: 100 addresses fetched
# ✅ Page 15: 100 addresses fetched
# ✅ Page 16: 100 addresses fetched
# ✅ Page 17: 100 addresses fetched
# ✅ Page 18: 100 addresses fetched
# ✅ Page 19: 100 addresses fetched
# ✅ Page 20: 100 addresses fetched
# ✅ Page 21: 100 addresses fetched
# ✅ Page 22: 100 addresses fetched
# ✅ Page 23: 100 addresses fetched
# ✅ Page 24: 100 addresses fetched
# ✅ Page 25: 100 addresses fetched
# ✅ Page 26: 100 addresses fetched
# ✅ Page 27: 100 addresses fetched
# ✅ Page 28: 100 addresses fetched
# ✅ Page 29: 100 addresses fetched
# ✅ Page 30: 100 addresses fetched
# ✅ Page 31: 100 addresses fetched
# ✅ Page 32: 100 addresses fetched
# ✅ Page 33: 100 addresses fetched
# ✅ Page 34: 100 addresses fetched
# ✅ Page 35: 100 addresses fetched
# ✅ Page 36: 100 addresses fetched
# ✅ Page 37: 100 addresses fetched
# ✅ Page 38: 100 addresses fetched
# ✅ Page 39: 100 addresses fetched
# ✅ Page 40: 100 addresses fetched
# ✅ Page 41: 100 addresses fetched
# ✅ Page 42: 100 addresses fetched
# ✅ Page 43: 100 addresses fetched
# ✅ Page 44: 100 addresses fetched
# ✅ Page 45: 100 addresses fetched
# ✅ Page 46: 100 addresses fetched
# ✅ Page 47: 100 addresses fetched
# ✅ Page 48: 100 addresses fetched
# ✅ Page 49: 100 addresses fetched
# ✅ Page 50: 100 addresses fetched
# ✅ Page 51: 100 addresses fetched
# ✅ Page 52: 100 addresses fetched
# ✅ Page 53: 100 addresses fetched
# ✅ Page 54: 100 addresses fetched
# ✅ Page 55: 100 addresses fetched
# ✅ Page 56: 100 addresses fetched
# ✅ Page 57: 100 addresses fetched
# ✅ Page 58: 100 addresses fetched
# ✅ Page 59: 100 addresses fetched
# ✅ Page 60: 100 addresses fetched
# ✅ Page 61: 100 addresses fetched
# ✅ Page 62: 100 addresses fetched
# ✅ Page 63: 100 addresses fetched
# ✅ Page 64: 100 addresses fetched
# ✅ Page 65: 100 addresses fetched
# ✅ Page 66: 100 addresses fetched
# ✅ Page 67: 100 addresses fetched
# ✅ Page 68: 100 addresses fetched
# ✅ Page 69: 100 addresses fetched
# ✅ Page 70: 100 addresses fetched
# ✅ Page 71: 100 addresses fetched
# ✅ Page 72: 100 addresses fetched
# ✅ Page 73: 100 addresses fetched
# ✅ Page 74: 100 addresses fetched
# ✅ Page 75: 100 addresses fetched
# ✅ Page 76: 100 addresses fetched
# ✅ Page 77: 100 addresses fetched
# ✅ Page 78: 100 addresses fetched
# ✅ Page 79: 100 addresses fetched
# ✅ Page 80: 100 addresses fetched
# ✅ Page 81: 100 addresses fetched
# ✅ Page 82: 100 addresses fetched
# ✅ Page 83: 100 addresses fetched
# ✅ Page 84: 100 addresses fetched
# ✅ Page 85: 100 addresses fetched
# ✅ Page 86: 100 addresses fetched
# ✅ Page 87: 100 addresses fetched
# ✅ Page 88: 100 addresses fetched
# ✅ Page 89: 100 addresses fetched
# ✅ Page 90: 100 addresses fetched
# ✅ Page 91: 100 addresses fetched
# ✅ Page 92: 100 addresses fetched
# ✅ Page 93: 100 addresses fetched
# ✅ Page 94: 100 addresses fetched
# ✅ Page 95: 100 addresses fetched
# ✅ Page 96: 100 addresses fetched
# ✅ Page 97: 100 addresses fetched
# ✅ Page 98: 100 addresses fetched
# ✅ Page 99: 100 addresses fetched
# ✅ Page 100: 100 addresses fetched
# ✅ Page 101: 100 addresses fetched
# ✅ Page 102: 100 addresses fetched
# ✅ Page 103: 100 addresses fetched
# ✅ Page 104: 100 addresses fetched
# ✅ Page 105: 100 addresses fetched
# ✅ Page 106: 100 addresses fetched
# ✅ Page 107: 100 addresses fetched
# ✅ Page 108: 100 addresses fetched
# ✅ Page 109: 100 addresses fetched
# ✅ Page 110: 100 addresses fetched
# ✅ Page 111: 100 addresses fetched
# ✅ Page 112: 100 addresses fetched
# ✅ Page 113: 100 addresses fetched
# ✅ Page 114: 100 addresses fetched
# ✅ Page 115: 100 addresses fetched
# ✅ Page 116: 100 addresses fetched
# ✅ Page 117: 100 addresses fetched
# ✅ Page 118: 100 addresses fetched
# ✅ Page 119: 100 addresses fetched
# ✅ Page 120: 100 addresses fetched
# ✅ Page 121: 100 addresses fetched
# ✅ Page 122: 100 addresses fetched
# ✅ Page 123: 100 addresses fetched
# ✅ Page 124: 100 addresses fetched
# ✅ Page 125: 100 addresses fetched
# ✅ Page 126: 100 addresses fetched
# ✅ Page 127: 100 addresses fetched
# ✅ Page 128: 100 addresses fetched
# ✅ Page 129: 100 addresses fetched
# ✅ Page 130: 100 addresses fetched
# ✅ Page 131: 100 addresses fetched
# ✅ Page 132: 100 addresses fetched
# ✅ Page 133: 100 addresses fetched
# ✅ Page 134: 100 addresses fetched
# ✅ Page 135: 100 addresses fetched
# ✅ Page 136: 100 addresses fetched
# ✅ Page 137: 100 addresses fetched
# ✅ Page 138: 100 addresses fetched
# ✅ Page 139: 100 addresses fetched
# ✅ Page 140: 100 addresses fetched
# ✅ Page 141: 100 addresses fetched
# ✅ Page 142: 100 addresses fetched
# ✅ Page 143: 100 addresses fetched
# ✅ Page 144: 100 addresses fetched
# ✅ Page 145: 100 addresses fetched
# ✅ Page 146: 100 addresses fetched
# ✅ Page 147: 100 addresses fetched
# ✅ Page 148: 100 addresses fetched
# ✅ Page 149: 100 addresses fetched
# ✅ Page 150: 100 addresses fetched
# ✅ Page 151: 100 addresses fetched
# ✅ Page 152: 100 addresses fetched
# ✅ Page 153: 100 addresses fetched
# ✅ Page 154: 100 addresses fetched
# ✅ Page 155: 100 addresses fetched
# ✅ Page 156: 100 addresses fetched
# ✅ Page 157: 100 addresses fetched
# ✅ Page 158: 100 addresses fetched
# ✅ Page 159: 100 addresses fetched
# ✅ Page 160: 100 addresses fetched
# ✅ Page 161: 100 addresses fetched
# ✅ Page 162: 100 addresses fetched
# ✅ Page 163: 100 addresses fetched
# ✅ Page 164: 100 addresses fetched
# ✅ Page 165: 100 addresses fetched
# ✅ Page 166: 100 addresses fetched
# ✅ Page 167: 100 addresses fetched
# ✅ Page 168: 100 addresses fetched
# ✅ Page 169: 100 addresses fetched
# ✅ Page 170: 87 addresses fetched
# 🚫 Page 171 is empty. Stopping fetch.
# 🎉 Done! Total holders: 16987. Saved to 'genius_yield_gens_holders.json'
# ✅ Script finished at 2025-07-24 20:56:52

# %%
import requests
import time
import json
from datetime import datetime

# === CONFIGURATION ===
BLOCKFROST_API_KEY = "mainnetD5tXDiNzInPOA8ABiVQjb9gBJxB2zqXu"
ASSET_CONCAT_ID = "8a1cfae21368b8bebbbed9800fec304e95cce39a2a57dc35e2e3ebaa4d494c4b"  # MILK
OUTPUT_PATH = "muesliswap_milk_holders.json"

MAX_RETRIES = 3
SLEEP_BETWEEN_PAGES = 0.8  # safe speed

# === INIT ===
url_base = f"https://cardano-mainnet.blockfrost.io/api/v0/assets/{ASSET_CONCAT_ID}/addresses"
headers = {"project_id": BLOCKFROST_API_KEY}
holders = []
page = 1
fetching = True

# === PAGINATED FETCH LOOP ===
while fetching:
    url = f"{url_base}?page={page}"
    attempt = 1
    success = False

    while attempt <= MAX_RETRIES:
        try:
            response = requests.get(url, headers=headers, timeout=20)

            # Check response is JSON
            if "application/json" not in response.headers.get("Content-Type", ""):
                print(f"❌ HTML error instead of JSON on page {page}")
                print(f"📎 Snippet:\n{response.text[:300]}")
                raise ValueError("Non-JSON response")

            if response.status_code == 200:
                page_data = response.json()

                if not page_data:
                    print(f"🚫 Page {page} is empty. Stopping.")
                    fetching = False
                    success = True
                    break

                holders.extend(page_data)
                print(f"✅ Page {page}: {len(page_data)} addresses fetched")
                success = True
                break
            else:
                print(f"⚠️ Attempt {attempt}: Status {response.status_code} - {response.text}")

        except Exception as e:
            print(f"⚠️ Attempt {attempt}: Exception - {e}")

        attempt += 1
        time.sleep(3)

    if not success:
        print(f"❌ Failed to fetch page {page}. Stopping.")
        break

    page += 1
    try:
        time.sleep(SLEEP_BETWEEN_PAGES)
    except KeyboardInterrupt:
        print("🛑 Interrupted. Exiting.")
        break

# === SAVE RESULTS ===
if holders:
    with open(OUTPUT_PATH, "w") as f:
        json.dump(holders, f, indent=2)
    print(f"🎉 Done! Total holders: {len(holders)}. Saved to '{OUTPUT_PATH}'")
else:
    print("⚠️ No data saved. Empty result.")

print(f"✅ Script finished at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ Page 1: 100 addresses fetched
# ✅ Page 2: 100 addresses fetched
# ✅ Page 3: 100 addresses fetched
# ✅ Page 4: 100 addresses fetched
# ✅ Page 5: 100 addresses fetched
# ✅ Page 6: 100 addresses fetched
# ✅ Page 7: 100 addresses fetched
# ✅ Page 8: 100 addresses fetched
# ✅ Page 9: 100 addresses fetched
# ✅ Page 10: 100 addresses fetched
# ✅ Page 11: 100 addresses fetched
# ✅ Page 12: 100 addresses fetched
# ✅ Page 13: 100 addresses fetched
# ✅ Page 14: 100 addresses fetched
# ✅ Page 15: 100 addresses fetched
# ✅ Page 16: 100 addresses fetched
# ✅ Page 17: 100 addresses fetched
# ✅ Page 18: 100 addresses fetched
# ✅ Page 19: 100 addresses fetched
# ✅ Page 20: 100 addresses fetched
# ✅ Page 21: 100 addresses fetched
# ✅ Page 22: 100 addresses fetched
# ✅ Page 23: 100 addresses fetched
# ✅ Page 24: 100 addresses fetched
# ✅ Page 25: 100 addresses fetched
# ✅ Page 26: 100 addresses fetched
# ✅ Page 27: 100 addresses fetched
# ✅ Page 28: 100 addresses fetched
# ✅ Page 29: 100 addresses fetched
# ✅ Page 30: 100 addresses fetched
# ✅ Page 31: 100 addresses fetched
# ✅ Page 32: 100 addresses fetched
# ✅ Page 33: 100 addresses fetched
# ✅ Page 34: 100 addresses fetched
# ✅ Page 35: 100 addresses fetched
# ✅ Page 36: 100 addresses fetched
# ✅ Page 37: 100 addresses fetched
# ✅ Page 38: 100 addresses fetched
# ✅ Page 39: 100 addresses fetched
# ✅ Page 40: 100 addresses fetched
# ✅ Page 41: 100 addresses fetched
# ✅ Page 42: 86 addresses fetched
# 🚫 Page 43 is empty. Stopping.
# 🎉 Done! Total holders: 4186. Saved to 'muesliswap_milk_holders.json'
# ✅ Script finished at 2025-07-24 21:23:58

# %%
import requests
import time
import json
from datetime import datetime

# === CONFIGURATION ===
BLOCKFROST_API_KEY = "mainnetD5tXDiNzInPOA8ABiVQjb9gBJxB2zqXu"
ASSET_CONCAT_ID = "29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c64d494e"
OUTPUT_PATH = "minswap_min_holders.json"
MAX_RETRIES = 5
SLEEP_BETWEEN_PAGES = 1.2  
TIMEOUT_SECONDS = 60

# === INIT ===
url_base = f"https://cardano-mainnet.blockfrost.io/api/v0/assets/{ASSET_CONCAT_ID}/addresses"
headers = {"project_id": BLOCKFROST_API_KEY}
holders = []
page = 1
fetching = True

# === PAGINATED FETCH ===
while fetching:
    url = f"{url_base}?page={page}"
    attempt = 1
    success = False

    while attempt <= MAX_RETRIES:
        try:
            response = requests.get(url, headers=headers, timeout=TIMEOUT_SECONDS)

            # Check if response is JSON
            if "application/json" not in response.headers.get("Content-Type", ""):
                print(f"❌ HTML error received instead of JSON on page {page}")
                print(f"📎 Response snippet:\n{response.text[:300]}")
                raise ValueError("Non-JSON response received")

            if response.status_code == 200:
                page_data = response.json()

                if not page_data:
                    print(f"🚫 Page {page} is empty. Stopping fetch.")
                    fetching = False
                    success = True
                    break

                holders.extend(page_data)
                print(f"✅ Page {page}: {len(page_data)} addresses fetched")
                success = True
                break
            else:
                print(f"⚠️ Attempt {attempt} on page {page}: {response.status_code} - {response.text}")

        except Exception as e:
            print(f"⚠️ Attempt {attempt} on page {page}: Exception - {e}")

        attempt += 1
        time.sleep(5)

    if not success:
        print(f"❌ Failed to fetch page {page}. Stopping.")
        break

    page += 1
    try:
        time.sleep(SLEEP_BETWEEN_PAGES)
    except KeyboardInterrupt:
        print("🛑 Manually interrupted during sleep. Exiting fetch loop.")
        break

# === SAVE TO FILE ===
if holders:
    with open(OUTPUT_PATH, "w") as f:
        json.dump(holders, f, indent=2)
    print(f"🎉 Done! Total holders: {len(holders)}. Saved to '{OUTPUT_PATH}'")
else:
    print("⚠️ No data saved. Holder list is empty.")

print(f"✅ Script finished at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ❌ HTML error received instead of JSON on page 1
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 1 on page 1: Exception - Non-JSON response received
# ❌ HTML error received instead of JSON on page 1
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 2 on page 1: Exception - Non-JSON response received
# ✅ Page 1: 100 addresses fetched
# ✅ Page 2: 100 addresses fetched
# ❌ HTML error received instead of JSON on page 3
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 1 on page 3: Exception - Non-JSON response received
# ✅ Page 3: 100 addresses fetched
# ✅ Page 4: 100 addresses fetched
# ✅ Page 5: 100 addresses fetched
# ✅ Page 6: 100 addresses fetched
# ✅ Page 7: 100 addresses fetched
# ✅ Page 8: 100 addresses fetched
# ✅ Page 9: 100 addresses fetched
# ✅ Page 10: 100 addresses fetched
# ✅ Page 11: 100 addresses fetched
# ✅ Page 12: 100 addresses fetched
# ✅ Page 13: 100 addresses fetched
# ✅ Page 14: 100 addresses fetched
# ❌ HTML error received instead of JSON on page 15
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 1 on page 15: Exception - Non-JSON response received
# ❌ HTML error received instead of JSON on page 15
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 2 on page 15: Exception - Non-JSON response received
# ✅ Page 15: 100 addresses fetched
# ✅ Page 16: 100 addresses fetched
# ✅ Page 17: 100 addresses fetched
# ✅ Page 18: 100 addresses fetched
# ✅ Page 19: 100 addresses fetched
# ✅ Page 20: 100 addresses fetched
# ✅ Page 21: 100 addresses fetched
# ✅ Page 22: 100 addresses fetched
# ✅ Page 23: 100 addresses fetched
# ✅ Page 24: 100 addresses fetched
# ✅ Page 25: 100 addresses fetched
# ✅ Page 26: 100 addresses fetched
# ✅ Page 27: 100 addresses fetched
# ✅ Page 28: 100 addresses fetched
# ✅ Page 29: 100 addresses fetched
# ✅ Page 30: 100 addresses fetched
# ✅ Page 31: 100 addresses fetched
# ✅ Page 32: 100 addresses fetched
# ✅ Page 33: 100 addresses fetched
# ✅ Page 34: 100 addresses fetched
# ✅ Page 35: 100 addresses fetched
# ✅ Page 36: 100 addresses fetched
# ✅ Page 37: 100 addresses fetched
# ✅ Page 38: 100 addresses fetched
# ✅ Page 39: 100 addresses fetched
# ✅ Page 40: 100 addresses fetched
# ✅ Page 41: 100 addresses fetched
# ✅ Page 42: 100 addresses fetched
# ✅ Page 43: 100 addresses fetched
# ✅ Page 44: 100 addresses fetched
# ✅ Page 45: 100 addresses fetched
# ✅ Page 46: 100 addresses fetched
# ✅ Page 47: 100 addresses fetched
# ✅ Page 48: 100 addresses fetched
# ✅ Page 49: 100 addresses fetched
# ✅ Page 50: 100 addresses fetched
# ✅ Page 51: 100 addresses fetched
# ✅ Page 52: 100 addresses fetched
# ✅ Page 53: 100 addresses fetched
# ✅ Page 54: 100 addresses fetched
# ✅ Page 55: 100 addresses fetched
# ✅ Page 56: 100 addresses fetched
# ✅ Page 57: 100 addresses fetched
# ✅ Page 58: 100 addresses fetched
# ✅ Page 59: 100 addresses fetched
# ✅ Page 60: 100 addresses fetched
# ✅ Page 61: 100 addresses fetched
# ✅ Page 62: 100 addresses fetched
# ✅ Page 63: 100 addresses fetched
# ✅ Page 64: 100 addresses fetched
# ✅ Page 65: 100 addresses fetched
# ✅ Page 66: 100 addresses fetched
# ✅ Page 67: 100 addresses fetched
# ✅ Page 68: 100 addresses fetched
# ✅ Page 69: 100 addresses fetched
# ✅ Page 70: 100 addresses fetched
# ✅ Page 71: 100 addresses fetched
# ✅ Page 72: 100 addresses fetched
# ✅ Page 73: 100 addresses fetched
# ✅ Page 74: 100 addresses fetched
# ✅ Page 75: 100 addresses fetched
# ✅ Page 76: 100 addresses fetched
# ✅ Page 77: 100 addresses fetched
# ✅ Page 78: 100 addresses fetched
# ✅ Page 79: 100 addresses fetched
# ✅ Page 80: 100 addresses fetched
# ✅ Page 81: 100 addresses fetched
# ✅ Page 82: 100 addresses fetched
# ✅ Page 83: 100 addresses fetched
# ✅ Page 84: 100 addresses fetched
# ✅ Page 85: 100 addresses fetched
# ✅ Page 86: 100 addresses fetched
# ✅ Page 87: 100 addresses fetched
# ✅ Page 88: 100 addresses fetched
# ✅ Page 89: 100 addresses fetched
# ✅ Page 90: 100 addresses fetched
# ✅ Page 91: 100 addresses fetched
# ✅ Page 92: 100 addresses fetched
# ✅ Page 93: 100 addresses fetched
# ✅ Page 94: 100 addresses fetched
# ✅ Page 95: 100 addresses fetched
# ✅ Page 96: 100 addresses fetched
# ✅ Page 97: 100 addresses fetched
# ✅ Page 98: 100 addresses fetched
# ✅ Page 99: 100 addresses fetched
# ✅ Page 100: 100 addresses fetched
# ✅ Page 101: 100 addresses fetched
# ✅ Page 102: 100 addresses fetched
# ✅ Page 103: 100 addresses fetched
# ✅ Page 104: 100 addresses fetched
# ✅ Page 105: 100 addresses fetched
# ✅ Page 106: 100 addresses fetched
# ✅ Page 107: 100 addresses fetched
# ✅ Page 108: 100 addresses fetched
# ✅ Page 109: 100 addresses fetched
# ✅ Page 110: 100 addresses fetched
# ✅ Page 111: 100 addresses fetched
# ✅ Page 112: 100 addresses fetched
# ✅ Page 113: 100 addresses fetched
# ✅ Page 114: 100 addresses fetched
# ✅ Page 115: 100 addresses fetched
# ✅ Page 116: 100 addresses fetched
# ✅ Page 117: 100 addresses fetched
# ✅ Page 118: 100 addresses fetched
# ✅ Page 119: 100 addresses fetched
# ✅ Page 120: 100 addresses fetched
# ✅ Page 121: 100 addresses fetched
# ✅ Page 122: 100 addresses fetched
# ✅ Page 123: 100 addresses fetched
# ✅ Page 124: 100 addresses fetched
# ✅ Page 125: 100 addresses fetched
# ✅ Page 126: 100 addresses fetched
# ✅ Page 127: 100 addresses fetched
# ✅ Page 128: 100 addresses fetched
# ✅ Page 129: 100 addresses fetched
# ✅ Page 130: 100 addresses fetched
# ✅ Page 131: 100 addresses fetched
# ✅ Page 132: 100 addresses fetched
# ✅ Page 133: 100 addresses fetched
# ✅ Page 134: 100 addresses fetched
# ✅ Page 135: 100 addresses fetched
# ✅ Page 136: 100 addresses fetched
# ✅ Page 137: 100 addresses fetched
# ✅ Page 138: 100 addresses fetched
# ✅ Page 139: 100 addresses fetched
# ✅ Page 140: 100 addresses fetched
# ✅ Page 141: 100 addresses fetched
# ✅ Page 142: 100 addresses fetched
# ✅ Page 143: 100 addresses fetched
# ✅ Page 144: 100 addresses fetched
# ✅ Page 145: 100 addresses fetched
# ✅ Page 146: 100 addresses fetched
# ✅ Page 147: 100 addresses fetched
# ✅ Page 148: 100 addresses fetched
# ✅ Page 149: 100 addresses fetched
# ✅ Page 150: 100 addresses fetched
# ✅ Page 151: 100 addresses fetched
# ✅ Page 152: 100 addresses fetched
# ✅ Page 153: 100 addresses fetched
# ✅ Page 154: 100 addresses fetched
# ✅ Page 155: 100 addresses fetched
# ✅ Page 156: 100 addresses fetched
# ✅ Page 157: 100 addresses fetched
# ✅ Page 158: 100 addresses fetched
# ✅ Page 159: 100 addresses fetched
# ✅ Page 160: 100 addresses fetched
# ✅ Page 161: 100 addresses fetched
# ✅ Page 162: 100 addresses fetched
# ✅ Page 163: 100 addresses fetched
# ✅ Page 164: 100 addresses fetched
# ✅ Page 165: 100 addresses fetched
# ✅ Page 166: 100 addresses fetched
# ✅ Page 167: 100 addresses fetched
# ✅ Page 168: 100 addresses fetched
# ✅ Page 169: 100 addresses fetched
# ✅ Page 170: 100 addresses fetched
# ✅ Page 171: 100 addresses fetched
# ✅ Page 172: 100 addresses fetched
# ✅ Page 173: 100 addresses fetched
# ✅ Page 174: 100 addresses fetched
# ✅ Page 175: 100 addresses fetched
# ✅ Page 176: 100 addresses fetched
# ✅ Page 177: 100 addresses fetched
# ✅ Page 178: 100 addresses fetched
# ✅ Page 179: 100 addresses fetched
# ✅ Page 180: 100 addresses fetched
# ✅ Page 181: 100 addresses fetched
# ✅ Page 182: 100 addresses fetched
# ✅ Page 183: 100 addresses fetched
# ✅ Page 184: 100 addresses fetched
# ✅ Page 185: 100 addresses fetched
# ✅ Page 186: 100 addresses fetched
# ✅ Page 187: 100 addresses fetched
# ✅ Page 188: 100 addresses fetched
# ✅ Page 189: 100 addresses fetched
# ✅ Page 190: 100 addresses fetched
# ✅ Page 191: 100 addresses fetched
# ✅ Page 192: 100 addresses fetched
# ✅ Page 193: 100 addresses fetched
# ✅ Page 194: 100 addresses fetched
# ✅ Page 195: 100 addresses fetched
# ✅ Page 196: 100 addresses fetched
# ✅ Page 197: 100 addresses fetched
# ✅ Page 198: 100 addresses fetched
# ✅ Page 199: 100 addresses fetched
# ✅ Page 200: 100 addresses fetched
# ✅ Page 201: 100 addresses fetched
# ✅ Page 202: 100 addresses fetched
# ✅ Page 203: 100 addresses fetched
# ✅ Page 204: 100 addresses fetched
# ✅ Page 205: 100 addresses fetched
# ✅ Page 206: 100 addresses fetched
# ✅ Page 207: 100 addresses fetched
# ✅ Page 208: 100 addresses fetched
# ✅ Page 209: 100 addresses fetched
# ✅ Page 210: 100 addresses fetched
# ✅ Page 211: 100 addresses fetched
# ✅ Page 212: 100 addresses fetched
# ✅ Page 213: 100 addresses fetched
# ✅ Page 214: 100 addresses fetched
# ✅ Page 215: 100 addresses fetched
# ✅ Page 216: 100 addresses fetched
# ✅ Page 217: 100 addresses fetched
# ✅ Page 218: 100 addresses fetched
# ✅ Page 219: 100 addresses fetched
# ✅ Page 220: 100 addresses fetched
# ✅ Page 221: 100 addresses fetched
# ✅ Page 222: 100 addresses fetched
# ✅ Page 223: 100 addresses fetched
# ✅ Page 224: 100 addresses fetched
# ✅ Page 225: 100 addresses fetched
# ✅ Page 226: 100 addresses fetched
# ✅ Page 227: 100 addresses fetched
# ✅ Page 228: 100 addresses fetched
# ✅ Page 229: 100 addresses fetched
# ✅ Page 230: 100 addresses fetched
# ✅ Page 231: 100 addresses fetched
# ✅ Page 232: 100 addresses fetched
# ✅ Page 233: 100 addresses fetched
# ✅ Page 234: 100 addresses fetched
# ✅ Page 235: 100 addresses fetched
# ✅ Page 236: 100 addresses fetched
# ✅ Page 237: 100 addresses fetched
# ✅ Page 238: 100 addresses fetched
# ✅ Page 239: 100 addresses fetched
# ✅ Page 240: 100 addresses fetched
# ✅ Page 241: 100 addresses fetched
# ✅ Page 242: 100 addresses fetched
# ✅ Page 243: 100 addresses fetched
# ✅ Page 244: 100 addresses fetched
# ✅ Page 245: 100 addresses fetched
# ✅ Page 246: 100 addresses fetched
# ✅ Page 247: 100 addresses fetched
# ✅ Page 248: 100 addresses fetched
# ✅ Page 249: 100 addresses fetched
# ✅ Page 250: 100 addresses fetched
# ✅ Page 251: 100 addresses fetched
# ✅ Page 252: 100 addresses fetched
# ✅ Page 253: 100 addresses fetched
# ✅ Page 254: 100 addresses fetched
# ✅ Page 255: 100 addresses fetched
# ✅ Page 256: 100 addresses fetched
# ✅ Page 257: 100 addresses fetched
# ✅ Page 258: 100 addresses fetched
# ✅ Page 259: 100 addresses fetched
# ✅ Page 260: 100 addresses fetched
# ✅ Page 261: 100 addresses fetched
# ✅ Page 262: 100 addresses fetched
# ✅ Page 263: 100 addresses fetched
# ✅ Page 264: 100 addresses fetched
# ✅ Page 265: 100 addresses fetched
# ✅ Page 266: 100 addresses fetched
# ✅ Page 267: 100 addresses fetched
# ✅ Page 268: 100 addresses fetched
# ✅ Page 269: 100 addresses fetched
# ✅ Page 270: 100 addresses fetched
# ✅ Page 271: 100 addresses fetched
# ✅ Page 272: 100 addresses fetched
# ✅ Page 273: 100 addresses fetched
# ✅ Page 274: 100 addresses fetched
# ✅ Page 275: 100 addresses fetched
# ✅ Page 276: 100 addresses fetched
# ✅ Page 277: 100 addresses fetched
# ✅ Page 278: 100 addresses fetched
# ✅ Page 279: 100 addresses fetched
# ✅ Page 280: 100 addresses fetched
# ✅ Page 281: 100 addresses fetched
# ✅ Page 282: 100 addresses fetched
# ✅ Page 283: 100 addresses fetched
# ✅ Page 284: 100 addresses fetched
# ✅ Page 285: 100 addresses fetched
# ✅ Page 286: 100 addresses fetched
# ✅ Page 287: 100 addresses fetched
# ✅ Page 288: 100 addresses fetched
# ✅ Page 289: 100 addresses fetched
# ✅ Page 290: 100 addresses fetched
# ✅ Page 291: 100 addresses fetched
# ✅ Page 292: 100 addresses fetched
# ✅ Page 293: 100 addresses fetched
# ✅ Page 294: 100 addresses fetched
# ✅ Page 295: 100 addresses fetched
# ✅ Page 296: 100 addresses fetched
# ✅ Page 297: 100 addresses fetched
# ✅ Page 298: 100 addresses fetched
# ✅ Page 299: 100 addresses fetched
# ✅ Page 300: 100 addresses fetched
# ✅ Page 301: 100 addresses fetched
# ✅ Page 302: 100 addresses fetched
# ✅ Page 303: 100 addresses fetched
# ✅ Page 304: 100 addresses fetched
# ✅ Page 305: 100 addresses fetched
# ✅ Page 306: 100 addresses fetched
# ✅ Page 307: 100 addresses fetched
# ✅ Page 308: 100 addresses fetched
# ✅ Page 309: 100 addresses fetched
# ✅ Page 310: 100 addresses fetched
# ✅ Page 311: 100 addresses fetched
# ✅ Page 312: 100 addresses fetched
# ✅ Page 313: 100 addresses fetched
# ✅ Page 314: 100 addresses fetched
# ✅ Page 315: 100 addresses fetched
# ✅ Page 316: 100 addresses fetched
# ✅ Page 317: 100 addresses fetched
# ✅ Page 318: 100 addresses fetched
# ✅ Page 319: 100 addresses fetched
# ✅ Page 320: 100 addresses fetched
# ✅ Page 321: 100 addresses fetched
# ✅ Page 322: 100 addresses fetched
# ✅ Page 323: 100 addresses fetched
# ✅ Page 324: 100 addresses fetched
# ✅ Page 325: 100 addresses fetched
# ✅ Page 326: 100 addresses fetched
# ✅ Page 327: 100 addresses fetched
# ✅ Page 328: 78 addresses fetched
# 🚫 Page 329 is empty. Stopping fetch.
# 🎉 Done! Total holders: 32778. Saved to 'minswap_min_holders.json'
# ✅ Script finished at 2025-07-24 21:38:34

# %%
import requests
import time
import json
from datetime import datetime

# === CONFIGURATION ===
BLOCKFROST_API_KEY = "mainnetD5tXDiNzInPOA8ABiVQjb9gBJxB2zqXu"
ASSET_CONCAT_ID = "c0ee29a85b13209423b10447d3c2e6a50641a15c57770e27cb9d507357696e67526964657273"
OUTPUT_PATH = "wingriders_wrt_holders.json"
MAX_RETRIES = 5
SLEEP_BETWEEN_PAGES = 1.2
TIMEOUT_SECONDS = 60

# === INIT ===
url_base = f"https://cardano-mainnet.blockfrost.io/api/v0/assets/{ASSET_CONCAT_ID}/addresses"
headers = {"project_id": BLOCKFROST_API_KEY}
holders = []
page = 1
fetching = True

# === PAGINATED FETCH ===
while fetching:
    url = f"{url_base}?page={page}"
    attempt = 1
    success = False

    while attempt <= MAX_RETRIES:
        try:
            response = requests.get(url, headers=headers, timeout=TIMEOUT_SECONDS)

            if "application/json" not in response.headers.get("Content-Type", ""):
                print(f"❌ HTML error received instead of JSON on page {page}")
                print(f"📎 Response snippet:\n{response.text[:300]}")
                raise ValueError("Non-JSON response received")

            if response.status_code == 200:
                page_data = response.json()

                if not page_data:
                    print(f"🚫 Page {page} is empty. Stopping fetch.")
                    fetching = False
                    success = True
                    break

                holders.extend(page_data)
                print(f"✅ Page {page}: {len(page_data)} addresses fetched")
                success = True
                break
            else:
                print(f"⚠️ Attempt {attempt} on page {page}: {response.status_code} - {response.text}")

        except Exception as e:
            print(f"⚠️ Attempt {attempt} on page {page}: Exception - {e}")

        attempt += 1
        time.sleep(5)

    if not success:
        print(f"❌ Failed to fetch page {page}. Stopping.")
        break

    page += 1
    try:
        time.sleep(SLEEP_BETWEEN_PAGES)
    except KeyboardInterrupt:
        print("🛑 Manually interrupted during sleep. Exiting fetch loop.")
        break

# === SAVE TO FILE ===
if holders:
    with open(OUTPUT_PATH, "w") as f:
        json.dump(holders, f, indent=2)
    print(f"🎉 Done! Total holders: {len(holders)}. Saved to '{OUTPUT_PATH}'")
else:
    print("⚠️ No data saved. Holder list is empty.")

print(f"✅ Script finished at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ❌ HTML error received instead of JSON on page 1
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 1 on page 1: Exception - Non-JSON response received
# ❌ HTML error received instead of JSON on page 1
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 2 on page 1: Exception - Non-JSON response received
# ✅ Page 1: 100 addresses fetched
# ✅ Page 2: 100 addresses fetched
# ✅ Page 3: 100 addresses fetched
# ✅ Page 4: 100 addresses fetched
# ✅ Page 5: 100 addresses fetched
# ✅ Page 6: 100 addresses fetched
# ✅ Page 7: 100 addresses fetched
# ✅ Page 8: 100 addresses fetched
# ✅ Page 9: 100 addresses fetched
# ✅ Page 10: 100 addresses fetched
# ✅ Page 11: 100 addresses fetched
# ✅ Page 12: 100 addresses fetched
# ✅ Page 13: 100 addresses fetched
# ✅ Page 14: 100 addresses fetched
# ✅ Page 15: 100 addresses fetched
# ✅ Page 16: 100 addresses fetched
# ✅ Page 17: 100 addresses fetched
# ✅ Page 18: 100 addresses fetched
# ✅ Page 19: 100 addresses fetched
# ✅ Page 20: 100 addresses fetched
# ✅ Page 21: 100 addresses fetched
# ✅ Page 22: 100 addresses fetched
# ✅ Page 23: 100 addresses fetched
# ✅ Page 24: 100 addresses fetched
# ✅ Page 25: 100 addresses fetched
# ✅ Page 26: 100 addresses fetched
# ✅ Page 27: 100 addresses fetched
# ✅ Page 28: 100 addresses fetched
# ✅ Page 29: 100 addresses fetched
# ✅ Page 30: 100 addresses fetched
# ✅ Page 31: 100 addresses fetched
# ✅ Page 32: 100 addresses fetched
# ✅ Page 33: 100 addresses fetched
# ✅ Page 34: 100 addresses fetched
# ✅ Page 35: 100 addresses fetched
# ✅ Page 36: 100 addresses fetched
# ✅ Page 37: 100 addresses fetched
# ✅ Page 38: 100 addresses fetched
# ✅ Page 39: 100 addresses fetched
# ✅ Page 40: 100 addresses fetched
# ✅ Page 41: 100 addresses fetched
# ✅ Page 42: 100 addresses fetched
# ✅ Page 43: 100 addresses fetched
# ✅ Page 44: 100 addresses fetched
# ✅ Page 45: 100 addresses fetched
# ✅ Page 46: 100 addresses fetched
# ✅ Page 47: 100 addresses fetched
# ✅ Page 48: 100 addresses fetched
# ✅ Page 49: 100 addresses fetched
# ✅ Page 50: 100 addresses fetched
# ✅ Page 51: 100 addresses fetched
# ✅ Page 52: 100 addresses fetched
# ✅ Page 53: 100 addresses fetched
# ✅ Page 54: 100 addresses fetched
# ✅ Page 55: 100 addresses fetched
# ✅ Page 56: 100 addresses fetched
# ✅ Page 57: 100 addresses fetched
# ✅ Page 58: 100 addresses fetched
# ✅ Page 59: 100 addresses fetched
# ✅ Page 60: 100 addresses fetched
# ✅ Page 61: 100 addresses fetched
# ✅ Page 62: 100 addresses fetched
# ✅ Page 63: 100 addresses fetched
# ✅ Page 64: 100 addresses fetched
# ✅ Page 65: 100 addresses fetched
# ✅ Page 66: 100 addresses fetched
# ✅ Page 67: 100 addresses fetched
# ✅ Page 68: 100 addresses fetched
# ✅ Page 69: 100 addresses fetched
# ✅ Page 70: 100 addresses fetched
# ✅ Page 71: 100 addresses fetched
# ✅ Page 72: 100 addresses fetched
# ✅ Page 73: 100 addresses fetched
# ✅ Page 74: 100 addresses fetched
# ✅ Page 75: 100 addresses fetched
# ✅ Page 76: 100 addresses fetched
# ✅ Page 77: 100 addresses fetched
# ✅ Page 78: 100 addresses fetched
# ✅ Page 79: 100 addresses fetched
# ✅ Page 80: 100 addresses fetched
# ✅ Page 81: 100 addresses fetched
# ✅ Page 82: 100 addresses fetched
# ✅ Page 83: 100 addresses fetched
# ✅ Page 84: 100 addresses fetched
# ✅ Page 85: 100 addresses fetched
# ✅ Page 86: 100 addresses fetched
# ✅ Page 87: 100 addresses fetched
# ✅ Page 88: 100 addresses fetched
# ✅ Page 89: 100 addresses fetched
# ✅ Page 90: 100 addresses fetched
# ✅ Page 91: 100 addresses fetched
# ✅ Page 92: 100 addresses fetched
# ✅ Page 93: 100 addresses fetched
# ✅ Page 94: 100 addresses fetched
# ✅ Page 95: 100 addresses fetched
# ✅ Page 96: 100 addresses fetched
# ✅ Page 97: 100 addresses fetched
# ✅ Page 98: 100 addresses fetched
# ✅ Page 99: 100 addresses fetched
# ✅ Page 100: 100 addresses fetched
# ✅ Page 101: 100 addresses fetched
# ✅ Page 102: 100 addresses fetched
# ✅ Page 103: 100 addresses fetched
# ✅ Page 104: 100 addresses fetched
# ✅ Page 105: 100 addresses fetched
# ✅ Page 106: 100 addresses fetched
# ✅ Page 107: 100 addresses fetched
# ✅ Page 108: 100 addresses fetched
# ✅ Page 109: 100 addresses fetched
# ✅ Page 110: 100 addresses fetched
# ✅ Page 111: 100 addresses fetched
# ✅ Page 112: 100 addresses fetched
# ✅ Page 113: 100 addresses fetched
# ✅ Page 114: 100 addresses fetched
# ✅ Page 115: 100 addresses fetched
# ✅ Page 116: 100 addresses fetched
# ✅ Page 117: 100 addresses fetched
# ✅ Page 118: 100 addresses fetched
# ✅ Page 119: 100 addresses fetched
# ✅ Page 120: 100 addresses fetched
# ✅ Page 121: 27 addresses fetched
# 🚫 Page 122 is empty. Stopping fetch.
# 🎉 Done! Total holders: 12027. Saved to 'wingriders_wrt_holders.json'
# ✅ Script finished at 2025-07-24 21:44:28

# %%
import requests
import time
import json
from datetime import datetime

# === CONFIGURATION ===
BLOCKFROST_API_KEY = "mainnetD5tXDiNzInPOA8ABiVQjb9gBJxB2zqXu"
ASSET_CONCAT_ID = "9a9693a9a37912a5097918f97918d15240c92ab729a0b7c4aa144d7753554e444145"
OUTPUT_PATH = "sundaeswap_SUNDAE_holders.json"
MAX_RETRIES = 5
SLEEP_BETWEEN_PAGES = 1.2
TIMEOUT_SECONDS = 60

# === INIT ===
url_base = f"https://cardano-mainnet.blockfrost.io/api/v0/assets/{ASSET_CONCAT_ID}/addresses"
headers = {"project_id": BLOCKFROST_API_KEY}
holders = []
page = 1
fetching = True

# === PAGINATED FETCH ===
while fetching:
    url = f"{url_base}?page={page}"
    attempt = 1
    success = False

    while attempt <= MAX_RETRIES:
        try:
            response = requests.get(url, headers=headers, timeout=TIMEOUT_SECONDS)

            if "application/json" not in response.headers.get("Content-Type", ""):
                print(f"❌ HTML error received instead of JSON on page {page}")
                print(f"📎 Response snippet:\n{response.text[:300]}")
                raise ValueError("Non-JSON response received")

            if response.status_code == 200:
                page_data = response.json()

                if not page_data:
                    print(f"🚫 Page {page} is empty. Stopping fetch.")
                    fetching = False
                    success = True
                    break

                holders.extend(page_data)
                print(f"✅ Page {page}: {len(page_data)} addresses fetched")
                success = True
                break
            else:
                print(f"⚠️ Attempt {attempt} on page {page}: {response.status_code} - {response.text}")

        except Exception as e:
            print(f"⚠️ Attempt {attempt} on page {page}: Exception - {e}")

        attempt += 1
        time.sleep(5)

    if not success:
        print(f"❌ Failed to fetch page {page}. Stopping.")
        break

    page += 1
    try:
        time.sleep(SLEEP_BETWEEN_PAGES)
    except KeyboardInterrupt:
        print("🛑 Manually interrupted during sleep. Exiting fetch loop.")
        break

# === SAVE TO FILE ===
if holders:
    with open(OUTPUT_PATH, "w") as f:
        json.dump(holders, f, indent=2)
    print(f"🎉 Done! Total holders: {len(holders)}. Saved to '{OUTPUT_PATH}'")
else:
    print("⚠️ No data saved. Holder list is empty.")

print(f"✅ Script finished at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ❌ HTML error received instead of JSON on page 1
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 1 on page 1: Exception - Non-JSON response received
# ✅ Page 1: 100 addresses fetched
# ✅ Page 2: 100 addresses fetched
# ✅ Page 3: 100 addresses fetched
# ❌ HTML error received instead of JSON on page 4
# 📎 Response snippet:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!
# ⚠️ Attempt 1 on page 4: Exception - Non-JSON response received
# ✅ Page 4: 100 addresses fetched
# ✅ Page 5: 100 addresses fetched
# ✅ Page 6: 100 addresses fetched
# ✅ Page 7: 100 addresses fetched
# ✅ Page 8: 100 addresses fetched
# ✅ Page 9: 100 addresses fetched
# ✅ Page 10: 100 addresses fetched
# ✅ Page 11: 100 addresses fetched
# ✅ Page 12: 100 addresses fetched
# ✅ Page 13: 100 addresses fetched
# ✅ Page 14: 100 addresses fetched
# ✅ Page 15: 100 addresses fetched
# ✅ Page 16: 100 addresses fetched
# ✅ Page 17: 100 addresses fetched
# ✅ Page 18: 100 addresses fetched
# ✅ Page 19: 100 addresses fetched
# ✅ Page 20: 100 addresses fetched
# ✅ Page 21: 100 addresses fetched
# ✅ Page 22: 100 addresses fetched
# ✅ Page 23: 100 addresses fetched
# ✅ Page 24: 100 addresses fetched
# ✅ Page 25: 100 addresses fetched
# ✅ Page 26: 100 addresses fetched
# ✅ Page 27: 100 addresses fetched
# ✅ Page 28: 100 addresses fetched
# ✅ Page 29: 100 addresses fetched
# ✅ Page 30: 100 addresses fetched
# ✅ Page 31: 100 addresses fetched
# ✅ Page 32: 100 addresses fetched
# ✅ Page 33: 100 addresses fetched
# ✅ Page 34: 100 addresses fetched
# ✅ Page 35: 100 addresses fetched
# ✅ Page 36: 100 addresses fetched
# ✅ Page 37: 100 addresses fetched
# ✅ Page 38: 100 addresses fetched
# ✅ Page 39: 100 addresses fetched
# ✅ Page 40: 100 addresses fetched
# ✅ Page 41: 100 addresses fetched
# ✅ Page 42: 100 addresses fetched
# ✅ Page 43: 100 addresses fetched
# ✅ Page 44: 100 addresses fetched
# ✅ Page 45: 100 addresses fetched
# ✅ Page 46: 100 addresses fetched
# ✅ Page 47: 100 addresses fetched
# ✅ Page 48: 100 addresses fetched
# ✅ Page 49: 100 addresses fetched
# ✅ Page 50: 100 addresses fetched
# ✅ Page 51: 100 addresses fetched
# ✅ Page 52: 100 addresses fetched
# ✅ Page 53: 100 addresses fetched
# ✅ Page 54: 100 addresses fetched
# ✅ Page 55: 100 addresses fetched
# ✅ Page 56: 100 addresses fetched
# ✅ Page 57: 100 addresses fetched
# ✅ Page 58: 100 addresses fetched
# ✅ Page 59: 100 addresses fetched
# ✅ Page 60: 100 addresses fetched
# ✅ Page 61: 100 addresses fetched
# ✅ Page 62: 100 addresses fetched
# ✅ Page 63: 100 addresses fetched
# ✅ Page 64: 100 addresses fetched
# ✅ Page 65: 100 addresses fetched
# ✅ Page 66: 100 addresses fetched
# ✅ Page 67: 100 addresses fetched
# ✅ Page 68: 100 addresses fetched
# ✅ Page 69: 100 addresses fetched
# ✅ Page 70: 100 addresses fetched
# ✅ Page 71: 100 addresses fetched
# ✅ Page 72: 100 addresses fetched
# ✅ Page 73: 100 addresses fetched
# ✅ Page 74: 100 addresses fetched
# ✅ Page 75: 100 addresses fetched
# ✅ Page 76: 100 addresses fetched
# ✅ Page 77: 100 addresses fetched
# ✅ Page 78: 100 addresses fetched
# ✅ Page 79: 100 addresses fetched
# ✅ Page 80: 100 addresses fetched
# ✅ Page 81: 100 addresses fetched
# ✅ Page 82: 100 addresses fetched
# ✅ Page 83: 100 addresses fetched
# ✅ Page 84: 100 addresses fetched
# ✅ Page 85: 100 addresses fetched
# ✅ Page 86: 100 addresses fetched
# ✅ Page 87: 100 addresses fetched
# ✅ Page 88: 100 addresses fetched
# ✅ Page 89: 100 addresses fetched
# ✅ Page 90: 100 addresses fetched
# ✅ Page 91: 100 addresses fetched
# ✅ Page 92: 100 addresses fetched
# ✅ Page 93: 100 addresses fetched
# ✅ Page 94: 100 addresses fetched
# ✅ Page 95: 100 addresses fetched
# ✅ Page 96: 100 addresses fetched
# ✅ Page 97: 100 addresses fetched
# ✅ Page 98: 100 addresses fetched
# ✅ Page 99: 100 addresses fetched
# ✅ Page 100: 100 addresses fetched
# ✅ Page 101: 100 addresses fetched
# ✅ Page 102: 100 addresses fetched
# ✅ Page 103: 100 addresses fetched
# ✅ Page 104: 100 addresses fetched
# ✅ Page 105: 100 addresses fetched
# ✅ Page 106: 100 addresses fetched
# ✅ Page 107: 100 addresses fetched
# ✅ Page 108: 100 addresses fetched
# ✅ Page 109: 100 addresses fetched
# ✅ Page 110: 100 addresses fetched
# ✅ Page 111: 100 addresses fetched
# ✅ Page 112: 100 addresses fetched
# ✅ Page 113: 100 addresses fetched
# ✅ Page 114: 100 addresses fetched
# ✅ Page 115: 100 addresses fetched
# ✅ Page 116: 100 addresses fetched
# ✅ Page 117: 100 addresses fetched
# ✅ Page 118: 100 addresses fetched
# ✅ Page 119: 100 addresses fetched
# ✅ Page 120: 100 addresses fetched
# ✅ Page 121: 100 addresses fetched
# ✅ Page 122: 100 addresses fetched
# ✅ Page 123: 100 addresses fetched
# ✅ Page 124: 100 addresses fetched
# ✅ Page 125: 100 addresses fetched
# ✅ Page 126: 100 addresses fetched
# ✅ Page 127: 100 addresses fetched
# ✅ Page 128: 100 addresses fetched
# ✅ Page 129: 100 addresses fetched
# ✅ Page 130: 100 addresses fetched
# ✅ Page 131: 100 addresses fetched
# ✅ Page 132: 100 addresses fetched
# ✅ Page 133: 100 addresses fetched
# ✅ Page 134: 100 addresses fetched
# ✅ Page 135: 100 addresses fetched
# ✅ Page 136: 100 addresses fetched
# ✅ Page 137: 100 addresses fetched
# ✅ Page 138: 100 addresses fetched
# ✅ Page 139: 100 addresses fetched
# ✅ Page 140: 100 addresses fetched
# ✅ Page 141: 100 addresses fetched
# ✅ Page 142: 100 addresses fetched
# ✅ Page 143: 100 addresses fetched
# ✅ Page 144: 100 addresses fetched
# ✅ Page 145: 100 addresses fetched
# ✅ Page 146: 100 addresses fetched
# ✅ Page 147: 100 addresses fetched
# ✅ Page 148: 100 addresses fetched
# ✅ Page 149: 100 addresses fetched
# ✅ Page 150: 100 addresses fetched
# ✅ Page 151: 100 addresses fetched
# ✅ Page 152: 100 addresses fetched
# ✅ Page 153: 100 addresses fetched
# ✅ Page 154: 100 addresses fetched
# ✅ Page 155: 100 addresses fetched
# ✅ Page 156: 100 addresses fetched
# ✅ Page 157: 100 addresses fetched
# ✅ Page 158: 100 addresses fetched
# ✅ Page 159: 100 addresses fetched
# ✅ Page 160: 100 addresses fetched
# ✅ Page 161: 100 addresses fetched
# ✅ Page 162: 100 addresses fetched
# ✅ Page 163: 100 addresses fetched
# ✅ Page 164: 100 addresses fetched
# ✅ Page 165: 100 addresses fetched
# ✅ Page 166: 100 addresses fetched
# ✅ Page 167: 100 addresses fetched
# ✅ Page 168: 100 addresses fetched
# ✅ Page 169: 100 addresses fetched
# ✅ Page 170: 100 addresses fetched
# ✅ Page 171: 100 addresses fetched
# ✅ Page 172: 100 addresses fetched
# ✅ Page 173: 100 addresses fetched
# ✅ Page 174: 100 addresses fetched
# ✅ Page 175: 100 addresses fetched
# ✅ Page 176: 100 addresses fetched
# ✅ Page 177: 100 addresses fetched
# ✅ Page 178: 100 addresses fetched
# ✅ Page 179: 100 addresses fetched
# ✅ Page 180: 100 addresses fetched
# ✅ Page 181: 100 addresses fetched
# ✅ Page 182: 100 addresses fetched
# ✅ Page 183: 100 addresses fetched
# ✅ Page 184: 100 addresses fetched
# ✅ Page 185: 100 addresses fetched
# ✅ Page 186: 100 addresses fetched
# ✅ Page 187: 100 addresses fetched
# ✅ Page 188: 100 addresses fetched
# ✅ Page 189: 100 addresses fetched
# ✅ Page 190: 100 addresses fetched
# ✅ Page 191: 100 addresses fetched
# ✅ Page 192: 100 addresses fetched
# ✅ Page 193: 100 addresses fetched
# ✅ Page 194: 100 addresses fetched
# ✅ Page 195: 100 addresses fetched
# ✅ Page 196: 100 addresses fetched
# ✅ Page 197: 100 addresses fetched
# ✅ Page 198: 100 addresses fetched
# ✅ Page 199: 100 addresses fetched
# ✅ Page 200: 100 addresses fetched
# ✅ Page 201: 100 addresses fetched
# ✅ Page 202: 100 addresses fetched
# ✅ Page 203: 100 addresses fetched
# ✅ Page 204: 100 addresses fetched
# ✅ Page 205: 100 addresses fetched
# ✅ Page 206: 100 addresses fetched
# ✅ Page 207: 100 addresses fetched
# ✅ Page 208: 100 addresses fetched
# ✅ Page 209: 100 addresses fetched
# ✅ Page 210: 100 addresses fetched
# ✅ Page 211: 100 addresses fetched
# ✅ Page 212: 100 addresses fetched
# ✅ Page 213: 100 addresses fetched
# ✅ Page 214: 100 addresses fetched
# ✅ Page 215: 100 addresses fetched
# ✅ Page 216: 100 addresses fetched
# ✅ Page 217: 100 addresses fetched
# ✅ Page 218: 100 addresses fetched
# ✅ Page 219: 100 addresses fetched
# ✅ Page 220: 100 addresses fetched
# ✅ Page 221: 100 addresses fetched
# ✅ Page 222: 100 addresses fetched
# ✅ Page 223: 100 addresses fetched
# ✅ Page 224: 100 addresses fetched
# ✅ Page 225: 100 addresses fetched
# ✅ Page 226: 100 addresses fetched
# ✅ Page 227: 100 addresses fetched
# ✅ Page 228: 100 addresses fetched
# ✅ Page 229: 100 addresses fetched
# ✅ Page 230: 100 addresses fetched
# ✅ Page 231: 100 addresses fetched
# ✅ Page 232: 100 addresses fetched
# ✅ Page 233: 100 addresses fetched
# ✅ Page 234: 100 addresses fetched
# ✅ Page 235: 100 addresses fetched
# ✅ Page 236: 100 addresses fetched
# ✅ Page 237: 100 addresses fetched
# ✅ Page 238: 100 addresses fetched
# ✅ Page 239: 100 addresses fetched
# ✅ Page 240: 100 addresses fetched
# ✅ Page 241: 100 addresses fetched
# ✅ Page 242: 100 addresses fetched
# ✅ Page 243: 100 addresses fetched
# ✅ Page 244: 100 addresses fetched
# ✅ Page 245: 100 addresses fetched
# ✅ Page 246: 100 addresses fetched
# ✅ Page 247: 100 addresses fetched
# ✅ Page 248: 100 addresses fetched
# ✅ Page 249: 100 addresses fetched
# ✅ Page 250: 100 addresses fetched
# ✅ Page 251: 100 addresses fetched
# ✅ Page 252: 100 addresses fetched
# ✅ Page 253: 100 addresses fetched
# ✅ Page 254: 100 addresses fetched
# ✅ Page 255: 100 addresses fetched
# ✅ Page 256: 100 addresses fetched
# ✅ Page 257: 100 addresses fetched
# ✅ Page 258: 100 addresses fetched
# ✅ Page 259: 100 addresses fetched
# ✅ Page 260: 100 addresses fetched
# ✅ Page 261: 100 addresses fetched
# ✅ Page 262: 100 addresses fetched
# ✅ Page 263: 100 addresses fetched
# ✅ Page 264: 100 addresses fetched
# ✅ Page 265: 100 addresses fetched
# ✅ Page 266: 100 addresses fetched
# ✅ Page 267: 100 addresses fetched
# ✅ Page 268: 100 addresses fetched
# ✅ Page 269: 100 addresses fetched
# ✅ Page 270: 100 addresses fetched
# ✅ Page 271: 100 addresses fetched
# ✅ Page 272: 100 addresses fetched
# ✅ Page 273: 100 addresses fetched
# ✅ Page 274: 100 addresses fetched
# ✅ Page 275: 100 addresses fetched
# ✅ Page 276: 100 addresses fetched
# ✅ Page 277: 100 addresses fetched
# ✅ Page 278: 100 addresses fetched
# ✅ Page 279: 100 addresses fetched
# ✅ Page 280: 100 addresses fetched
# ✅ Page 281: 100 addresses fetched
# ✅ Page 282: 100 addresses fetched
# ✅ Page 283: 100 addresses fetched
# ✅ Page 284: 100 addresses fetched
# ✅ Page 285: 100 addresses fetched
# ✅ Page 286: 100 addresses fetched
# ✅ Page 287: 100 addresses fetched
# ✅ Page 288: 100 addresses fetched
# ✅ Page 289: 100 addresses fetched
# ✅ Page 290: 100 addresses fetched
# ✅ Page 291: 100 addresses fetched
# ✅ Page 292: 100 addresses fetched
# ✅ Page 293: 100 addresses fetched
# ✅ Page 294: 100 addresses fetched
# ✅ Page 295: 100 addresses fetched
# ✅ Page 296: 100 addresses fetched
# ✅ Page 297: 100 addresses fetched
# ✅ Page 298: 100 addresses fetched
# ✅ Page 299: 100 addresses fetched
# ✅ Page 300: 100 addresses fetched
# ✅ Page 301: 100 addresses fetched
# ✅ Page 302: 100 addresses fetched
# ✅ Page 303: 100 addresses fetched
# ✅ Page 304: 100 addresses fetched
# ✅ Page 305: 100 addresses fetched
# ✅ Page 306: 100 addresses fetched
# ✅ Page 307: 100 addresses fetched
# ✅ Page 308: 100 addresses fetched
# ✅ Page 309: 100 addresses fetched
# ✅ Page 310: 100 addresses fetched
# ✅ Page 311: 100 addresses fetched
# ✅ Page 312: 100 addresses fetched
# ✅ Page 313: 100 addresses fetched
# ✅ Page 314: 100 addresses fetched
# ✅ Page 315: 100 addresses fetched
# ✅ Page 316: 100 addresses fetched
# ✅ Page 317: 100 addresses fetched
# ✅ Page 318: 100 addresses fetched
# ✅ Page 319: 100 addresses fetched
# ✅ Page 320: 100 addresses fetched
# ✅ Page 321: 100 addresses fetched
# ✅ Page 322: 100 addresses fetched
# ✅ Page 323: 100 addresses fetched
# ✅ Page 324: 100 addresses fetched
# ✅ Page 325: 100 addresses fetched
# ✅ Page 326: 100 addresses fetched
# ✅ Page 327: 100 addresses fetched
# ✅ Page 328: 100 addresses fetched
# ✅ Page 329: 100 addresses fetched
# ✅ Page 330: 100 addresses fetched
# ✅ Page 331: 100 addresses fetched
# ✅ Page 332: 100 addresses fetched
# ✅ Page 333: 100 addresses fetched
# ✅ Page 334: 100 addresses fetched
# ✅ Page 335: 100 addresses fetched
# ✅ Page 336: 100 addresses fetched
# ✅ Page 337: 100 addresses fetched
# ✅ Page 338: 100 addresses fetched
# ✅ Page 339: 100 addresses fetched
# ✅ Page 340: 100 addresses fetched
# ✅ Page 341: 100 addresses fetched
# ✅ Page 342: 100 addresses fetched
# ✅ Page 343: 100 addresses fetched
# ✅ Page 344: 100 addresses fetched
# ✅ Page 345: 100 addresses fetched
# ✅ Page 346: 100 addresses fetched
# ✅ Page 347: 100 addresses fetched
# ✅ Page 348: 100 addresses fetched
# ✅ Page 349: 100 addresses fetched
# ✅ Page 350: 100 addresses fetched
# ✅ Page 351: 100 addresses fetched
# ✅ Page 352: 100 addresses fetched
# ✅ Page 353: 100 addresses fetched
# ✅ Page 354: 100 addresses fetched
# ✅ Page 355: 100 addresses fetched
# ✅ Page 356: 100 addresses fetched
# ✅ Page 357: 100 addresses fetched
# ✅ Page 358: 100 addresses fetched
# ✅ Page 359: 100 addresses fetched
# ✅ Page 360: 100 addresses fetched
# ✅ Page 361: 100 addresses fetched
# ✅ Page 362: 100 addresses fetched
# ✅ Page 363: 100 addresses fetched
# ✅ Page 364: 100 addresses fetched
# ✅ Page 365: 100 addresses fetched
# ✅ Page 366: 100 addresses fetched
# ✅ Page 367: 100 addresses fetched
# ✅ Page 368: 100 addresses fetched
# ✅ Page 369: 100 addresses fetched
# ✅ Page 370: 100 addresses fetched
# ✅ Page 371: 100 addresses fetched
# ✅ Page 372: 100 addresses fetched
# ✅ Page 373: 100 addresses fetched
# ✅ Page 374: 100 addresses fetched
# ✅ Page 375: 100 addresses fetched
# ✅ Page 376: 100 addresses fetched
# ✅ Page 377: 100 addresses fetched
# ✅ Page 378: 100 addresses fetched
# ✅ Page 379: 100 addresses fetched
# ✅ Page 380: 100 addresses fetched
# ✅ Page 381: 100 addresses fetched
# ✅ Page 382: 100 addresses fetched
# ✅ Page 383: 100 addresses fetched
# ✅ Page 384: 100 addresses fetched
# ✅ Page 385: 100 addresses fetched
# ✅ Page 386: 100 addresses fetched
# ✅ Page 387: 100 addresses fetched
# ✅ Page 388: 100 addresses fetched
# ✅ Page 389: 100 addresses fetched
# ✅ Page 390: 100 addresses fetched
# ✅ Page 391: 100 addresses fetched
# ✅ Page 392: 100 addresses fetched
# ✅ Page 393: 100 addresses fetched
# ✅ Page 394: 100 addresses fetched
# ✅ Page 395: 100 addresses fetched
# ✅ Page 396: 100 addresses fetched
# ✅ Page 397: 100 addresses fetched
# ✅ Page 398: 100 addresses fetched
# ✅ Page 399: 100 addresses fetched
# ✅ Page 400: 100 addresses fetched
# ✅ Page 401: 100 addresses fetched
# ✅ Page 402: 100 addresses fetched
# ✅ Page 403: 100 addresses fetched
# ✅ Page 404: 100 addresses fetched
# ✅ Page 405: 100 addresses fetched
# ✅ Page 406: 100 addresses fetched
# ✅ Page 407: 100 addresses fetched
# ✅ Page 408: 100 addresses fetched
# ✅ Page 409: 100 addresses fetched
# ✅ Page 410: 100 addresses fetched
# ✅ Page 411: 100 addresses fetched
# ✅ Page 412: 100 addresses fetched
# ✅ Page 413: 100 addresses fetched
# ✅ Page 414: 100 addresses fetched
# ✅ Page 415: 100 addresses fetched
# ✅ Page 416: 100 addresses fetched
# ✅ Page 417: 100 addresses fetched
# ✅ Page 418: 100 addresses fetched
# ✅ Page 419: 100 addresses fetched
# ✅ Page 420: 100 addresses fetched
# ✅ Page 421: 100 addresses fetched
# ✅ Page 422: 100 addresses fetched
# ✅ Page 423: 100 addresses fetched
# ✅ Page 424: 100 addresses fetched
# ✅ Page 425: 100 addresses fetched
# ✅ Page 426: 100 addresses fetched
# ✅ Page 427: 100 addresses fetched
# ✅ Page 428: 100 addresses fetched
# ✅ Page 429: 100 addresses fetched
# ✅ Page 430: 100 addresses fetched
# ✅ Page 431: 100 addresses fetched
# ✅ Page 432: 100 addresses fetched
# ✅ Page 433: 100 addresses fetched
# ✅ Page 434: 100 addresses fetched
# ✅ Page 435: 100 addresses fetched
# ✅ Page 436: 100 addresses fetched
# ✅ Page 437: 100 addresses fetched
# ✅ Page 438: 100 addresses fetched
# ✅ Page 439: 100 addresses fetched
# ✅ Page 440: 100 addresses fetched
# ✅ Page 441: 100 addresses fetched
# ✅ Page 442: 100 addresses fetched
# ✅ Page 443: 100 addresses fetched
# ✅ Page 444: 100 addresses fetched
# ✅ Page 445: 100 addresses fetched
# ✅ Page 446: 100 addresses fetched
# ✅ Page 447: 100 addresses fetched
# ✅ Page 448: 100 addresses fetched
# ✅ Page 449: 100 addresses fetched
# ✅ Page 450: 100 addresses fetched
# ✅ Page 451: 100 addresses fetched
# ✅ Page 452: 100 addresses fetched
# ✅ Page 453: 100 addresses fetched
# ✅ Page 454: 100 addresses fetched
# ✅ Page 455: 100 addresses fetched
# ✅ Page 456: 100 addresses fetched
# ✅ Page 457: 100 addresses fetched
# ✅ Page 458: 100 addresses fetched
# ✅ Page 459: 100 addresses fetched
# ✅ Page 460: 100 addresses fetched
# ✅ Page 461: 100 addresses fetched
# ✅ Page 462: 100 addresses fetched
# ✅ Page 463: 100 addresses fetched
# ✅ Page 464: 100 addresses fetched
# ✅ Page 465: 100 addresses fetched
# ✅ Page 466: 100 addresses fetched
# ✅ Page 467: 100 addresses fetched
# ✅ Page 468: 100 addresses fetched
# ✅ Page 469: 100 addresses fetched
# ✅ Page 470: 100 addresses fetched
# ✅ Page 471: 100 addresses fetched
# ✅ Page 472: 100 addresses fetched
# ✅ Page 473: 100 addresses fetched
# ✅ Page 474: 100 addresses fetched
# ✅ Page 475: 100 addresses fetched
# ✅ Page 476: 100 addresses fetched
# ✅ Page 477: 100 addresses fetched
# ✅ Page 478: 100 addresses fetched
# ✅ Page 479: 100 addresses fetched
# ✅ Page 480: 100 addresses fetched
# ✅ Page 481: 100 addresses fetched
# ✅ Page 482: 100 addresses fetched
# ✅ Page 483: 100 addresses fetched
# ✅ Page 484: 100 addresses fetched
# ✅ Page 485: 100 addresses fetched
# ✅ Page 486: 100 addresses fetched
# ✅ Page 487: 100 addresses fetched
# ✅ Page 488: 100 addresses fetched
# ✅ Page 489: 100 addresses fetched
# ✅ Page 490: 100 addresses fetched
# ✅ Page 491: 100 addresses fetched
# ✅ Page 492: 100 addresses fetched
# ✅ Page 493: 100 addresses fetched
# ✅ Page 494: 100 addresses fetched
# ✅ Page 495: 100 addresses fetched
# ✅ Page 496: 100 addresses fetched
# ✅ Page 497: 100 addresses fetched
# ✅ Page 498: 100 addresses fetched
# ✅ Page 499: 100 addresses fetched
# ✅ Page 500: 100 addresses fetched
# ✅ Page 501: 100 addresses fetched
# ✅ Page 502: 100 addresses fetched
# ✅ Page 503: 100 addresses fetched
# ✅ Page 504: 100 addresses fetched
# ✅ Page 505: 100 addresses fetched
# ✅ Page 506: 100 addresses fetched
# ✅ Page 507: 100 addresses fetched
# ✅ Page 508: 100 addresses fetched
# ✅ Page 509: 100 addresses fetched
# ✅ Page 510: 100 addresses fetched
# ✅ Page 511: 100 addresses fetched
# ✅ Page 512: 100 addresses fetched
# ✅ Page 513: 100 addresses fetched
# ✅ Page 514: 100 addresses fetched
# ✅ Page 515: 100 addresses fetched
# ✅ Page 516: 100 addresses fetched
# ✅ Page 517: 100 addresses fetched
# ✅ Page 518: 100 addresses fetched
# ✅ Page 519: 100 addresses fetched
# ✅ Page 520: 100 addresses fetched
# ✅ Page 521: 100 addresses fetched
# ✅ Page 522: 100 addresses fetched
# ✅ Page 523: 100 addresses fetched
# ✅ Page 524: 100 addresses fetched
# ✅ Page 525: 100 addresses fetched
# ✅ Page 526: 100 addresses fetched
# ✅ Page 527: 100 addresses fetched
# ✅ Page 528: 100 addresses fetched
# ✅ Page 529: 100 addresses fetched
# ✅ Page 530: 100 addresses fetched
# ✅ Page 531: 100 addresses fetched
# ✅ Page 532: 100 addresses fetched
# ✅ Page 533: 100 addresses fetched
# ✅ Page 534: 100 addresses fetched
# ✅ Page 535: 100 addresses fetched
# ✅ Page 536: 100 addresses fetched
# ✅ Page 537: 100 addresses fetched
# ✅ Page 538: 100 addresses fetched
# ✅ Page 539: 100 addresses fetched
# ✅ Page 540: 100 addresses fetched
# ✅ Page 541: 100 addresses fetched
# ✅ Page 542: 100 addresses fetched
# ✅ Page 543: 100 addresses fetched
# ✅ Page 544: 100 addresses fetched
# ✅ Page 545: 100 addresses fetched
# ✅ Page 546: 100 addresses fetched
# ✅ Page 547: 100 addresses fetched
# ✅ Page 548: 100 addresses fetched
# ✅ Page 549: 100 addresses fetched
# ✅ Page 550: 100 addresses fetched
# ✅ Page 551: 100 addresses fetched
# ✅ Page 552: 100 addresses fetched
# ✅ Page 553: 100 addresses fetched
# ✅ Page 554: 100 addresses fetched
# ✅ Page 555: 100 addresses fetched
# ✅ Page 556: 100 addresses fetched
# ✅ Page 557: 100 addresses fetched
# ✅ Page 558: 100 addresses fetched
# ✅ Page 559: 100 addresses fetched
# ✅ Page 560: 100 addresses fetched
# ✅ Page 561: 100 addresses fetched
# ✅ Page 562: 100 addresses fetched
# ✅ Page 563: 100 addresses fetched
# ✅ Page 564: 100 addresses fetched
# ✅ Page 565: 100 addresses fetched
# ✅ Page 566: 100 addresses fetched
# ✅ Page 567: 100 addresses fetched
# ✅ Page 568: 100 addresses fetched
# ✅ Page 569: 100 addresses fetched
# ✅ Page 570: 100 addresses fetched
# ✅ Page 571: 100 addresses fetched
# ✅ Page 572: 100 addresses fetched
# ✅ Page 573: 100 addresses fetched
# ✅ Page 574: 100 addresses fetched
# ✅ Page 575: 100 addresses fetched
# ✅ Page 576: 100 addresses fetched
# ✅ Page 577: 100 addresses fetched
# ✅ Page 578: 100 addresses fetched
# ✅ Page 579: 100 addresses fetched
# ✅ Page 580: 100 addresses fetched
# ✅ Page 581: 100 addresses fetched
# ✅ Page 582: 100 addresses fetched
# ✅ Page 583: 100 addresses fetched
# ✅ Page 584: 100 addresses fetched
# ✅ Page 585: 100 addresses fetched
# ✅ Page 586: 100 addresses fetched
# ✅ Page 587: 100 addresses fetched
# ✅ Page 588: 100 addresses fetched
# ✅ Page 589: 100 addresses fetched
# ✅ Page 590: 100 addresses fetched
# ✅ Page 591: 100 addresses fetched
# ✅ Page 592: 100 addresses fetched
# ✅ Page 593: 100 addresses fetched
# ✅ Page 594: 100 addresses fetched
# ✅ Page 595: 100 addresses fetched
# ✅ Page 596: 100 addresses fetched
# ✅ Page 597: 100 addresses fetched
# ✅ Page 598: 100 addresses fetched
# ✅ Page 599: 100 addresses fetched
# ✅ Page 600: 100 addresses fetched
# ✅ Page 601: 100 addresses fetched
# ✅ Page 602: 100 addresses fetched
# ✅ Page 603: 100 addresses fetched
# ✅ Page 604: 100 addresses fetched
# ✅ Page 605: 100 addresses fetched
# ✅ Page 606: 100 addresses fetched
# ✅ Page 607: 100 addresses fetched
# ✅ Page 608: 100 addresses fetched
# ✅ Page 609: 100 addresses fetched
# ✅ Page 610: 100 addresses fetched
# ✅ Page 611: 100 addresses fetched
# ✅ Page 612: 100 addresses fetched
# ✅ Page 613: 100 addresses fetched
# ✅ Page 614: 100 addresses fetched
# ✅ Page 615: 100 addresses fetched
# ✅ Page 616: 100 addresses fetched
# ✅ Page 617: 100 addresses fetched
# ✅ Page 618: 100 addresses fetched
# ✅ Page 619: 100 addresses fetched
# ✅ Page 620: 100 addresses fetched
# ✅ Page 621: 100 addresses fetched
# ✅ Page 622: 100 addresses fetched
# ✅ Page 623: 100 addresses fetched
# ✅ Page 624: 100 addresses fetched
# ✅ Page 625: 100 addresses fetched
# ✅ Page 626: 100 addresses fetched
# ✅ Page 627: 100 addresses fetched
# ✅ Page 628: 100 addresses fetched
# ✅ Page 629: 100 addresses fetched
# ✅ Page 630: 100 addresses fetched
# ✅ Page 631: 100 addresses fetched
# ✅ Page 632: 100 addresses fetched
# ✅ Page 633: 100 addresses fetched
# ✅ Page 634: 100 addresses fetched
# ✅ Page 635: 100 addresses fetched
# ✅ Page 636: 100 addresses fetched
# ✅ Page 637: 100 addresses fetched
# ✅ Page 638: 100 addresses fetched
# ✅ Page 639: 100 addresses fetched
# ✅ Page 640: 100 addresses fetched
# ✅ Page 641: 100 addresses fetched
# ✅ Page 642: 100 addresses fetched
# ✅ Page 643: 100 addresses fetched
# ✅ Page 644: 100 addresses fetched
# ✅ Page 645: 100 addresses fetched
# ✅ Page 646: 100 addresses fetched
# ✅ Page 647: 100 addresses fetched
# ✅ Page 648: 100 addresses fetched
# ✅ Page 649: 100 addresses fetched
# ✅ Page 650: 100 addresses fetched
# ✅ Page 651: 100 addresses fetched
# ✅ Page 652: 100 addresses fetched
# ✅ Page 653: 100 addresses fetched
# ✅ Page 654: 100 addresses fetched
# ✅ Page 655: 100 addresses fetched
# ✅ Page 656: 100 addresses fetched
# ✅ Page 657: 100 addresses fetched
# ✅ Page 658: 100 addresses fetched
# ✅ Page 659: 100 addresses fetched
# ✅ Page 660: 100 addresses fetched
# ✅ Page 661: 100 addresses fetched
# ✅ Page 662: 100 addresses fetched
# ✅ Page 663: 100 addresses fetched
# ✅ Page 664: 100 addresses fetched
# ✅ Page 665: 100 addresses fetched
# ✅ Page 666: 100 addresses fetched
# ✅ Page 667: 100 addresses fetched
# ✅ Page 668: 100 addresses fetched
# ✅ Page 669: 100 addresses fetched
# ✅ Page 670: 100 addresses fetched
# ✅ Page 671: 100 addresses fetched
# ✅ Page 672: 100 addresses fetched
# ✅ Page 673: 100 addresses fetched
# ✅ Page 674: 100 addresses fetched
# ✅ Page 675: 100 addresses fetched
# ✅ Page 676: 100 addresses fetched
# ✅ Page 677: 100 addresses fetched
# ✅ Page 678: 100 addresses fetched
# ✅ Page 679: 100 addresses fetched
# ✅ Page 680: 100 addresses fetched
# ✅ Page 681: 100 addresses fetched
# ✅ Page 682: 100 addresses fetched
# ✅ Page 683: 100 addresses fetched
# ✅ Page 684: 100 addresses fetched
# ✅ Page 685: 100 addresses fetched
# ✅ Page 686: 100 addresses fetched
# ✅ Page 687: 100 addresses fetched
# ✅ Page 688: 100 addresses fetched
# ✅ Page 689: 100 addresses fetched
# ✅ Page 690: 100 addresses fetched
# ✅ Page 691: 100 addresses fetched
# ✅ Page 692: 100 addresses fetched
# ✅ Page 693: 100 addresses fetched
# ✅ Page 694: 100 addresses fetched
# ✅ Page 695: 100 addresses fetched
# ✅ Page 696: 100 addresses fetched
# ✅ Page 697: 100 addresses fetched
# ✅ Page 698: 100 addresses fetched
# ✅ Page 699: 100 addresses fetched
# ✅ Page 700: 100 addresses fetched
# ✅ Page 701: 100 addresses fetched
# ✅ Page 702: 100 addresses fetched
# ✅ Page 703: 100 addresses fetched
# ✅ Page 704: 100 addresses fetched
# ✅ Page 705: 100 addresses fetched
# ✅ Page 706: 100 addresses fetched
# ✅ Page 707: 100 addresses fetched
# ✅ Page 708: 100 addresses fetched
# ✅ Page 709: 100 addresses fetched
# ✅ Page 710: 100 addresses fetched
# ✅ Page 711: 100 addresses fetched
# ✅ Page 712: 100 addresses fetched
# ✅ Page 713: 100 addresses fetched
# ✅ Page 714: 100 addresses fetched
# ✅ Page 715: 100 addresses fetched
# ✅ Page 716: 100 addresses fetched
# ✅ Page 717: 100 addresses fetched
# ✅ Page 718: 100 addresses fetched
# ✅ Page 719: 100 addresses fetched
# ✅ Page 720: 100 addresses fetched
# ✅ Page 721: 100 addresses fetched
# ✅ Page 722: 100 addresses fetched
# ✅ Page 723: 100 addresses fetched
# ✅ Page 724: 100 addresses fetched
# ✅ Page 725: 100 addresses fetched
# ✅ Page 726: 100 addresses fetched
# ✅ Page 727: 100 addresses fetched
# ✅ Page 728: 100 addresses fetched
# ✅ Page 729: 100 addresses fetched
# ✅ Page 730: 100 addresses fetched
# ✅ Page 731: 100 addresses fetched
# ✅ Page 732: 100 addresses fetched
# ✅ Page 733: 100 addresses fetched
# ✅ Page 734: 100 addresses fetched
# ✅ Page 735: 100 addresses fetched
# ✅ Page 736: 100 addresses fetched
# ✅ Page 737: 100 addresses fetched
# ✅ Page 738: 100 addresses fetched
# ✅ Page 739: 100 addresses fetched
# ✅ Page 740: 100 addresses fetched
# ✅ Page 741: 100 addresses fetched
# ✅ Page 742: 100 addresses fetched
# ✅ Page 743: 100 addresses fetched
# ✅ Page 744: 100 addresses fetched
# ✅ Page 745: 100 addresses fetched
# ✅ Page 746: 100 addresses fetched
# ✅ Page 747: 100 addresses fetched
# ✅ Page 748: 100 addresses fetched
# ✅ Page 749: 100 addresses fetched
# ✅ Page 750: 100 addresses fetched
# ✅ Page 751: 100 addresses fetched
# ✅ Page 752: 100 addresses fetched
# ✅ Page 753: 100 addresses fetched
# ✅ Page 754: 100 addresses fetched
# ✅ Page 755: 100 addresses fetched
# ✅ Page 756: 100 addresses fetched
# ✅ Page 757: 100 addresses fetched
# ✅ Page 758: 100 addresses fetched
# ✅ Page 759: 100 addresses fetched
# ✅ Page 760: 100 addresses fetched
# ✅ Page 761: 100 addresses fetched
# ✅ Page 762: 100 addresses fetched
# ✅ Page 763: 100 addresses fetched
# ✅ Page 764: 100 addresses fetched
# ✅ Page 765: 100 addresses fetched
# ✅ Page 766: 100 addresses fetched
# ✅ Page 767: 100 addresses fetched
# ✅ Page 768: 100 addresses fetched
# ✅ Page 769: 100 addresses fetched
# ✅ Page 770: 100 addresses fetched
# ✅ Page 771: 100 addresses fetched
# ✅ Page 772: 100 addresses fetched
# ✅ Page 773: 100 addresses fetched
# ✅ Page 774: 100 addresses fetched
# ✅ Page 775: 100 addresses fetched
# ✅ Page 776: 100 addresses fetched
# ✅ Page 777: 100 addresses fetched
# ✅ Page 778: 100 addresses fetched
# ✅ Page 779: 100 addresses fetched
# ✅ Page 780: 100 addresses fetched
# ✅ Page 781: 100 addresses fetched
# ✅ Page 782: 100 addresses fetched
# ✅ Page 783: 100 addresses fetched
# ✅ Page 784: 100 addresses fetched
# ✅ Page 785: 100 addresses fetched
# ✅ Page 786: 100 addresses fetched
# ✅ Page 787: 100 addresses fetched
# ✅ Page 788: 100 addresses fetched
# ✅ Page 789: 100 addresses fetched
# ✅ Page 790: 100 addresses fetched
# ✅ Page 791: 100 addresses fetched
# ✅ Page 792: 100 addresses fetched
# ✅ Page 793: 100 addresses fetched
# ✅ Page 794: 100 addresses fetched
# ✅ Page 795: 100 addresses fetched
# ✅ Page 796: 100 addresses fetched
# ✅ Page 797: 100 addresses fetched
# ✅ Page 798: 100 addresses fetched
# ✅ Page 799: 100 addresses fetched
# ✅ Page 800: 100 addresses fetched
# ✅ Page 801: 100 addresses fetched
# ✅ Page 802: 100 addresses fetched
# ✅ Page 803: 100 addresses fetched
# ✅ Page 804: 100 addresses fetched
# ✅ Page 805: 100 addresses fetched
# ✅ Page 806: 100 addresses fetched
# ✅ Page 807: 100 addresses fetched
# ✅ Page 808: 100 addresses fetched
# ✅ Page 809: 100 addresses fetched
# ✅ Page 810: 100 addresses fetched
# ✅ Page 811: 100 addresses fetched
# ✅ Page 812: 100 addresses fetched
# ✅ Page 813: 100 addresses fetched
# ✅ Page 814: 100 addresses fetched
# ✅ Page 815: 100 addresses fetched
# ✅ Page 816: 100 addresses fetched
# ✅ Page 817: 100 addresses fetched
# ✅ Page 818: 100 addresses fetched
# ✅ Page 819: 100 addresses fetched
# ✅ Page 820: 100 addresses fetched
# ✅ Page 821: 100 addresses fetched
# ✅ Page 822: 100 addresses fetched
# ✅ Page 823: 100 addresses fetched
# ✅ Page 824: 100 addresses fetched
# ✅ Page 825: 100 addresses fetched
# ✅ Page 826: 100 addresses fetched
# ✅ Page 827: 100 addresses fetched
# ✅ Page 828: 100 addresses fetched
# ✅ Page 829: 100 addresses fetched
# ✅ Page 830: 100 addresses fetched
# ✅ Page 831: 100 addresses fetched
# ✅ Page 832: 100 addresses fetched
# ✅ Page 833: 100 addresses fetched
# ✅ Page 834: 100 addresses fetched
# ✅ Page 835: 100 addresses fetched
# ✅ Page 836: 100 addresses fetched
# ✅ Page 837: 100 addresses fetched
# ✅ Page 838: 100 addresses fetched
# ✅ Page 839: 100 addresses fetched
# ✅ Page 840: 100 addresses fetched
# ✅ Page 841: 100 addresses fetched
# ✅ Page 842: 100 addresses fetched
# ✅ Page 843: 100 addresses fetched
# ✅ Page 844: 100 addresses fetched
# ✅ Page 845: 100 addresses fetched
# ✅ Page 846: 100 addresses fetched
# ✅ Page 847: 100 addresses fetched
# ✅ Page 848: 100 addresses fetched
# ✅ Page 849: 100 addresses fetched
# ✅ Page 850: 100 addresses fetched
# ✅ Page 851: 100 addresses fetched
# ✅ Page 852: 100 addresses fetched
# ✅ Page 853: 100 addresses fetched
# ✅ Page 854: 100 addresses fetched
# ✅ Page 855: 100 addresses fetched
# ✅ Page 856: 100 addresses fetched
# ✅ Page 857: 100 addresses fetched
# ✅ Page 858: 100 addresses fetched
# ✅ Page 859: 100 addresses fetched
# ✅ Page 860: 100 addresses fetched
# ✅ Page 861: 100 addresses fetched
# ✅ Page 862: 100 addresses fetched
# ✅ Page 863: 100 addresses fetched
# ✅ Page 864: 100 addresses fetched
# ✅ Page 865: 100 addresses fetched
# ✅ Page 866: 100 addresses fetched
# ✅ Page 867: 100 addresses fetched
# ✅ Page 868: 100 addresses fetched
# ✅ Page 869: 100 addresses fetched
# ✅ Page 870: 100 addresses fetched
# ✅ Page 871: 100 addresses fetched
# ✅ Page 872: 100 addresses fetched
# ✅ Page 873: 100 addresses fetched
# ✅ Page 874: 100 addresses fetched
# ✅ Page 875: 100 addresses fetched
# ✅ Page 876: 100 addresses fetched
# ✅ Page 877: 100 addresses fetched
# ✅ Page 878: 100 addresses fetched
# ✅ Page 879: 100 addresses fetched
# ✅ Page 880: 100 addresses fetched
# ✅ Page 881: 100 addresses fetched
# ✅ Page 882: 100 addresses fetched
# ✅ Page 883: 100 addresses fetched
# ✅ Page 884: 100 addresses fetched
# ✅ Page 885: 100 addresses fetched
# ✅ Page 886: 100 addresses fetched
# ✅ Page 887: 100 addresses fetched
# ✅ Page 888: 100 addresses fetched
# ✅ Page 889: 100 addresses fetched
# ✅ Page 890: 100 addresses fetched
# ✅ Page 891: 100 addresses fetched
# ✅ Page 892: 100 addresses fetched
# ✅ Page 893: 100 addresses fetched
# ✅ Page 894: 100 addresses fetched
# ✅ Page 895: 100 addresses fetched
# ✅ Page 896: 100 addresses fetched
# ✅ Page 897: 100 addresses fetched
# ✅ Page 898: 100 addresses fetched
# ✅ Page 899: 100 addresses fetched
# ✅ Page 900: 100 addresses fetched
# ✅ Page 901: 100 addresses fetched
# ✅ Page 902: 100 addresses fetched
# ✅ Page 903: 100 addresses fetched
# ✅ Page 904: 100 addresses fetched
# ✅ Page 905: 100 addresses fetched
# ✅ Page 906: 100 addresses fetched
# ✅ Page 907: 100 addresses fetched
# ✅ Page 908: 100 addresses fetched
# ✅ Page 909: 100 addresses fetched
# ✅ Page 910: 100 addresses fetched
# ✅ Page 911: 100 addresses fetched
# ✅ Page 912: 100 addresses fetched
# ✅ Page 913: 38 addresses fetched
# 🚫 Page 914 is empty. Stopping fetch.
# 🎉 Done! Total holders: 91238. Saved to 'sundaeswap_SUNDAE_holders.json'
# ✅ Script finished at 2025-07-24 22:16:44

# %% [markdown]
# # Make them to be Dataframe

# %%
# === Load JSON file ===
with open("wingriders_wrt_holders.json", "r") as f:
    data = json.load(f)

# === Parse into DataFrame ===
WRT_holders_df = pd.DataFrame([{
    "token": "WRT",
    "bech32_address": entry["address"],
    "quantity": int(entry["quantity"])
} for entry in data])

# === Optional: sort by quantity descending ===
WRT_holders_df = WRT_holders_df.sort_values(by="quantity", ascending=False).reset_index(drop=True)

# === Show preview ===
print(WRT_holders_df.head())
# Out:
#   token                                     bech32_address        quantity
# 0   WRT  addr1wypr0np3xatwhddulsnj3aaac65qg768zgs2xpd2x...  18802768670327
# 1   WRT  addr1zxhew7fmsup08qvhdnkg8ccra88pw7q5trrncja3d...  15889017227655
# 2   WRT  addr1wy9z0v8mrkhtyll43fu6mnhu0p87tna48xt4p5649...  13797083749206
# 3   WRT  addr1q8fhnpzgdukm4fc8xatkpx6kmdev7h22ze8nm52l6...   8805566666666
# 4   WRT  addr1qyr6ddcy3cc0srahvqxkzxctr4h84nml9ngtsdlue...   7560817668505

# %%
# === Load JSON file ===
with open("sundaeswap_sundae_holders.json", "r") as f:
    data = json.load(f)

# === Parse into DataFrame ===
SUNDAE_holders_df = pd.DataFrame([{
    "token": "SUNDAE",
    "bech32_address": entry["address"],
    "quantity": int(entry["quantity"])
} for entry in data])

# === Optional: sort by quantity descending ===
SUNDAE_holders_df = SUNDAE_holders_df.sort_values(by="quantity", ascending=False).reset_index(drop=True)

# === Show preview ===
print(SUNDAE_holders_df.head())
# Out:
#     token                                     bech32_address         quantity
# 0  SUNDAE  addr1w9742z4fewans7ry6cjp95pc4ecv7y54cx298lp5q...  660000000000000
# 1  SUNDAE  addr1z8srqftqemf0mjlukfszd97ljuxdp44r372txfcr7...  244714351879802
# 2  SUNDAE  addr1q95vk0ufx0g76xrgt8h74uvtha386735en3sng38d...  108601423359914
# 3  SUNDAE  addr1wyv9f6gz32y5jm5hw2j53qnjn5t92nuwmxhj0mrqg...   90101210271085
# 4  SUNDAE  addr1qyg45ed0w6eur2k283nju4usc4vt5sntxrrn47ela...   76890387542655

# %%
# === Load JSON file ===
with open("muesliswap_milk_holders.json", "r") as f:
    data = json.load(f)

# === Parse into DataFrame ===
MILK_holders_df = pd.DataFrame([{
    "token": "MILK",
    "bech32_address": entry["address"],
    "quantity": int(entry["quantity"])
} for entry in data])

# === Optional: sort by quantity descending ===
MILK_holders_df = MILK_holders_df.sort_values(by="quantity", ascending=False).reset_index(drop=True)

# === Show preview ===
print(MILK_holders_df.head())
# Out:
#   token                                     bech32_address  quantity
# 0  MILK  addr1q9rtclgcvqwhutjnkr3acfgetxn2f6qjkzjcdc4m5...   7089683
# 1  MILK  addr1qxfskza5zy0l5j2u4hwsegvrmv446a5x6954nq6rq...   1329203
# 2  MILK  addr1qygtklglhrru2y4hja2h09d3ejtvy2ekxnyk9w47c...    271945
# 3  MILK  addr1zyq0kyrml023kwjk8zr86d5gaxrt5w8lxnah8r6m6...    166203
# 4  MILK  addr1qx4z4rhewajfp76elhcl4v832a6c3splvzg6xgx5z...    114892

# %%
# === Load JSON file ===
with open("minswap_min_holders.json", "r") as f:
    data = json.load(f)

# === Parse into DataFrame ===
MIN_holders_df = pd.DataFrame([{
    "token": "MIN",
    "bech32_address": entry["address"],
    "quantity": int(entry["quantity"])
} for entry in data])

# === Optional: sort by quantity descending ===
MIN_holders_df = MIN_holders_df.sort_values(by="quantity", ascending=False).reset_index(drop=True)

# === Show preview ===
print(MIN_holders_df.head())
# Out:
#   token                                     bech32_address         quantity
# 0   MIN  addr1zx0wxal6dz7rjzxk2mwfvj9564rp9uajqrscftx44...  998422624088847
# 1   MIN  addr1w9jk84m6fk5p4yvrr35dry4ramhmqdq0zdq4rz4w0...  428049739523097
# 2   MIN  addr1z84q0denmyep98ph3tmzwsmw0j7zau9ljmsqx6a4r...  234793515755785
# 3   MIN  addr1z87vw6ts32hywu4j4kyk9qfgd36zhzx3y7fc786vg...  229125022327324
# 4   MIN  addr1wy3fscaws62d59k6qqhg3xsarx7vstzczgjmdhx2j...  207620627540886

# %%
# === Load JSON file ===
with open("genius_yield_gens_holders.json", "r") as f:
    data = json.load(f)

# === Parse into DataFrame ===
GENS_holders_df = pd.DataFrame([{
    "token": "GENS",
    "bech32_address": entry["address"],
    "quantity": int(entry["quantity"])
} for entry in data])

# === Optional: sort by quantity descending ===
GENS_holders_df = GENS_holders_df.sort_values(by="quantity", ascending=False).reset_index(drop=True)

# === Show preview ===
print(GENS_holders_df.head())
# Out:
#   token                                     bech32_address        quantity
# 0  GENS  addr1w8r99sv75y9tqfdzkzyqdqhedgnef47w4x7y0qnyt...  49239973887509
# 1  GENS  addr1qxn4kd8jfrmaz2atgevhdjpa3960yycec84jcg5ns...   2188888557244
# 2  GENS  addr1q9wcps6z0dynwhqh0f7mmvfnrf48c47dms208gtjn...   1931545644200
# 3  GENS  addr1z84q0denmyep98ph3tmzwsmw0j7zau9ljmsqx6a4r...   1903410702243
# 4  GENS  addr1vy38wnftcwrugm2umfyzr76rj9vqfp6rsc5vak22f...   1550805270786

# %%
# === Blockfrost Configuration ===
API_KEY = "mainnetD5tXDiNzInPOA8ABiVQjb9gBJxB2zqXu"
headers = {"project_id": API_KEY}

# === Asset ID List ===
asset_ids = [
    # GENS
    "dda5fdb1002f7389b33e036b6afee82a8189becb6cba852e8b79b4fb0014df1047454e53",
    # MILK
    "8a1cfae21368b8bebbbed9800fec304e95cce39a2a57dc35e2e3ebaa4d494c4b",
    # MIN
    "29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c64d494e",
    # WRT
    "c0ee29a85b13209423b10447d3c2e6a50641a15c57770e27cb9d507357696e67526964657273",
    # SUNDAE
    "9a9693a9a37912a5097918f97918d15240c92ab729a0b7c4aa144d7753554e444145"
]

# === Query and Print Decimals ===
for aid in asset_ids:
    try:
        response = requests.get(
            f"https://cardano-mainnet.blockfrost.io/api/v0/assets/{aid}",
            headers=headers,
            timeout=15
        )
        response.raise_for_status()
        metadata = response.json().get("metadata", {})
        decimals = metadata.get("decimals", None)
        print(f"{aid} → decimals = {decimals}")
    except Exception as e:
        print(f"{aid} → ❌ Error: {e}")
# Out:
# dda5fdb1002f7389b33e036b6afee82a8189becb6cba852e8b79b4fb0014df1047454e53 → decimals = 6
# 8a1cfae21368b8bebbbed9800fec304e95cce39a2a57dc35e2e3ebaa4d494c4b → decimals = 0
# 29d222ce763455e3d7a09a665ce554f00ac89d2e99a1a83d267170c64d494e → decimals = 6
# c0ee29a85b13209423b10447d3c2e6a50641a15c57770e27cb9d507357696e67526964657273 → decimals = 6
# 9a9693a9a37912a5097918f97918d15240c92ab729a0b7c4aa144d7753554e444145 → decimals = 6

# %% [markdown]
# # Deal with Quantity Decimals and Define Holders are those hold with at Least One Token Amount

# %%
# === Token Decimals Mapping ===
token_decimals = {
    "WRT": 6,
    "SUNDAE": 6,
    "MILK": 0,
    "MIN": 6,
    "GENS": 6,
}

def add_token_amount(df, token_name):
    decimals = token_decimals.get(token_name, 0)
    df["token_amount"] = df["quantity"].astype(float) / (10 ** decimals)
    df = df[df["token_amount"] >= 1].reset_index(drop=True)  #only left holders who hold at least 1 token.
    return df

# === Apply to all your existing token dfs ===
WRT_holders_df = add_token_amount(WRT_holders_df, "WRT")
SUNDAE_holders_df = add_token_amount(SUNDAE_holders_df, "SUNDAE")
MILK_holders_df = add_token_amount(MILK_holders_df, "MILK")
MIN_holders_df = add_token_amount(MIN_holders_df, "MIN")
GENS_holders_df = add_token_amount(GENS_holders_df, "GENS")

# %%
pd.options.display.float_format = "{:.6f}".format

# %%
SUNDAE_holders_df.head()
# Out:
#     token                                     bech32_address         quantity  \
# 0  SUNDAE  addr1w9742z4fewans7ry6cjp95pc4ecv7y54cx298lp5q...  660000000000000
# 1  SUNDAE  addr1z8srqftqemf0mjlukfszd97ljuxdp44r372txfcr7...  244714351879802
# 2  SUNDAE  addr1q95vk0ufx0g76xrgt8h74uvtha386735en3sng38d...  108601423359914
# 3  SUNDAE  addr1wyv9f6gz32y5jm5hw2j53qnjn5t92nuwmxhj0mrqg...   90101210271085
# 4  SUNDAE  addr1qyg45ed0w6eur2k283nju4usc4vt5sntxrrn47ela...   76890387542655
#
#       token_amount
# 0 660000000.000000
# 1 244714351.879802
# 2 108601423.359914
# 3  90101210.271085
# 4  76890387.542655

# %%
GENS_holders_df['bech32_address'][16986]
# Out:
# 'addr1q9tak4pwag00uzhtsd8gsfw5ya5vr374mhj0zxzanw7ar3dcvtjm8enawhyjjkcf6eves2cwz4c8y9tvhjuzpvmu4rwsum2dzf'

# %%
MILK_holders_df.tail()
# Out:
#      token                                     bech32_address  quantity  \
# 4181  MILK  addr1q8r3hzgmv0fga9fzmm30ak5ecqf4yz8ch6c8n7vz3...         1
# 4182  MILK  addr1q8mhpak6hcf0jt5yycrkval5sdde4plgycvvynznd...         1
# 4183  MILK  addr1q8t7y4z7uj7rz9sxgjpc3sck7lyur42l6j4jghgys...         1
# 4184  MILK  addr1qyzzjguu93at6f4eygyhuz627xqv0musna20jw66r...         1
# 4185  MILK  addr1qynhphtxrdzwx32h494qllflfqrh5d6jc8u4ddhfg...         1
#
#       token_amount
# 4181      1.000000
# 4182      1.000000
# 4183      1.000000
# 4184      1.000000
# 4185      1.000000

# %%
# === Compute both raw and unique holder counts for each token ===
token_holder_stats = []

for token, df in {
    "WRT": WRT_holders_df,
    "SUNDAE": SUNDAE_holders_df,
    "MILK": MILK_holders_df,
    "MIN": MIN_holders_df,
    "GENS": GENS_holders_df,
}.items():
    total_rows = len(df)
    unique_holders = df["bech32_address"].nunique()
    token_holder_stats.append({
        "Token": token,
        "Address Records": total_rows,
        "Unique Holders": unique_holders
    })

# === Display as DataFrame ===
token_holder_stats_df = pd.DataFrame(token_holder_stats)
print(token_holder_stats_df)
# Out:
#     Token  Address Records  Unique Holders
# 0     WRT             9978            9978
# 1  SUNDAE            81661           81661
# 2    MILK             4186            4186
# 3     MIN            25840           25840
# 4    GENS            13652           13652

# %% [markdown]
# # Change Bech32 Address to Hex Address

# %%
# === Add hex_address column to each df ===
WRT_holders_df["hex_address"]    = WRT_holders_df["bech32_address"].apply(safe_bech32_to_hex)
SUNDAE_holders_df["hex_address"] = SUNDAE_holders_df["bech32_address"].apply(safe_bech32_to_hex)
MILK_holders_df["hex_address"]   = MILK_holders_df["bech32_address"].apply(safe_bech32_to_hex)
MIN_holders_df["hex_address"]    = MIN_holders_df["bech32_address"].apply(safe_bech32_to_hex)
GENS_holders_df["hex_address"]   = GENS_holders_df["bech32_address"].apply(safe_bech32_to_hex)

# %% [markdown]
# # Save Token Holder Dataframes

# %%
WRT_holders_df.to_csv("WRT_holders_df.csv", index=False)

# %%
SUNDAE_holders_df.to_csv("SUNDAE_holders_df.csv", index=False)

# %%
MILK_holders_df.to_csv("MILK_holders_df.csv", index=False)

# %%
MIN_holders_df.to_csv("MIN_holders_df.csv", index=False)

# %%
GENS_holders_df.to_csv("GENS_holders_df.csv", index=False)
